# %%
import sys; sys.path.append("../strumenti")
from LO import LO
from SG import SG
import numpy as np
import matplotlib.pyplot as plt

# %%
myLO = LO("COM4")

# %%
ip_sg = '192.168.40.15'
sg = SG(ip_sg)

# %%
myLO.set_frequency(4)
sg.set_freq(4000000010)

# %%
import sys; sys.path.append("../strumenti")
from OSC import OSC

# %%
ip_osc = '192.168.40.20'
osc = OSC(ip_osc)
# Out:
# device connected.

# %%
ch1 = osc.acquire_data("CH1")
ch2 = osc.acquire_data("CH2")

# %%
print(ch1)
L1 = len(ch1)
print (L1)
L2 = len(ch2)
print (L2)
X = np.linspace (1, 10000, 10000)

fig, ax = plt.subplots (2,1)

ax[0].plot (X, ch1, color = "purple")
ax[0].plot (X, ch2, color = "red")
ax[1].plot (ch2, ch1, color = "blue")

plt.show ()
# Out:
# [64.0, 64.0, 63.0, 61.0, 62.0, 61.0, 62.0, 60.0, 60.0, 61.0, 60.0, 62.0, 60.0, 60.0, 58.0, 60.0, 58.0, 58.0, 57.0, 58.0, 58.0, 56.0, 57.0, 55.0, 55.0, 54.0, 55.0, 53.0, 52.0, 55.0, 50.0, 54.0, 50.0, 52.0, 51.0, 52.0, 52.0, 50.0, 48.0, 49.0, 48.0, 47.0, 48.0, 48.0, 47.0, 46.0, 46.0, 46.0, 46.0, 45.0, 45.0, 44.0, 44.0, 42.0, 42.0, 44.0, 44.0, 42.0, 42.0, 40.0, 41.0, 41.0, 38.0, 41.0, 39.0, 38.0, 39.0, 40.0, 36.0, 36.0, 37.0, 39.0, 36.0, 34.0, 37.0, 34.0, 35.0, 35.0, 35.0, 33.0, 34.0, 31.0, 32.0, 31.0, 31.0, 33.0, 31.0, 30.0, 29.0, 29.0, 30.0, 29.0, 29.0, 28.0, 27.0, 27.0, 30.0, 26.0, 26.0, 25.0, 26.0, 25.0, 23.0, 23.0, 23.0, 23.0, 22.0, 24.0, 22.0, 21.0, 21.0, 21.0, 18.0, 20.0, 20.0, 19.0, 18.0, 19.0, 18.0, 18.0, 17.0, 16.0, 17.0, 16.0, 16.0, 15.0, 14.0, 15.0, 13.0, 13.0, 14.0, 13.0, 14.0, 13.0, 11.0, 10.0, 11.0, 11.0, 9.0, 10.0, 9.0, 10.0, 9.0, 8.0, 8.0, 6.0, 7.0, 6.0, 5.0, 5.0, 2.0, 3.0, 4.0, 3.0, 4.0, 3.0, 2.0, 4.0, 2.0, 2.0, 0.0, 3.0, 3.0, -1.0, -1.0, 0.0, -2.0, 0.0, -1.0, -2.0, -1
# ...
