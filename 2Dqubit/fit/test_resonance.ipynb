# %%
import numpy as np
import matplotlib.pyplot as plt
import sys 
sys.path.append("../fit")
sys.path.append("../data")
import resonance
files = np.array(["500mK_-20dBm", "20mK_-20dBm"])

fr_list = []
Qc_list = []

for elem in files :

    file_path = f"../data/Resonances/{elem}.txt"
    fr, qc = resonance.fit(file_path)
    fr_list.append(fr)
    Qc_list.append(qc)

print(fr_list)
print(Qc_list)
# Out:
# 1000
# success of the fit:  True
# Chi-squared: 1298.42
# Degrees of freedom: 992
# Reduced Chi-squared: 1.31
# p-value: 0.0000
# a = 0.877 +/- 0.000
# b = -0.000 +/- 0.000
# c = -0.000 +/- 0.000
# d = 0.000 +/- 0.000
# k = 0.036 +/- 0.000
# phi = -0.314 +/- 0.000
# Qt = 562.987 +/- 0.000
# Qc = 903.519 +/- 0.000
# fr = 5476999999.985 +/- 0.027
# 1000
# success of the fit:  True
# Chi-squared: 1226.55
# Degrees of freedom: 992
# Reduced Chi-squared: 1.24
# p-value: 0.0000
# a = 0.872 +/- 0.000
# b = -0.000 +/- 0.000
# c = 0.000 +/- 0.000
# d = 0.000 +/- 0.000
# k = 0.050 +/- 0.000
# phi = -0.320 +/- 0.000
# Qt = 935.656 +/- 0.000
# Qc = 1469.020 +/- 0.000
# fr = 5478749373.292 +/- 0.471
# [5476999999.985365, 5478749373.292455]
# [903.5190358946954, 1469.0200576494838]
