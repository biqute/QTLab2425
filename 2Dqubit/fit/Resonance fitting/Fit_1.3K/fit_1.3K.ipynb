# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
import iminuit as minuit
from iminuit import Minuit
from iminuit.cost import LeastSquares
sys.path.append("..")
import resonance_fit

# %% [markdown]
# # FIT PRIMA RISONANZA 1.3K -50dBm

# %%
file_path = f"Cavity_resonances_1.3K/res1-50dBm.txt"

initial_params = {
    'a': 1,  # Ultimo valore di fr ottenuto
    'b': 10e-9,  # Ultimo valore di Qc ottenuto
    'c': 10e-18,       # Impostazione predefinita per c, d, k, phi, Qt, Qc, fr
    'd': 10e-27,
    'k': 2.5,
    'phi': 0.04,
    'Qt': 5703,
    'delta_Q': 50080,
    'fr': 4395812616  # Ultima frequenza di risonanza come valore iniziale
}


fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path, None, None, 4.39450e9, 4.39535e9, initial_params=initial_params)
Qi = 1/qt - 1/qc
print(f"Qi = {Qi}")
# Out:
# Fit riuscito: True
# Chi quadro ridotto: 18.214355170635958
# fr = 4394890896.233 Hz, Qt = 20657.36, Qc = 26729.04
# a = -7.476e-03 ± 1.396e-06
# b = 3.931e-08 ± 5.635e-12
# c = 2.620e-14 ± 1.674e-17
# d = -1.758e-19 ± 1.009e-21
# k = 9.998e-01 ± 1.687e-06
# phi = 6.121e-02 ± 3.556e-06
# Qt = 2.066e+04 ± 1.622e-01
# delta_Q = 6.072e+03 ± 1.783e-01
# fr = 4.395e+09 ± 1.196e+01
# Qi = 1.0996404991125747e-05

# %% [markdown]
# # FIT SECONDA RISONANZA 1.3K -50dBm

# %%
file_path = f"Cavity_resonances_1.3K/res2-50dBm.txt"


initial_params = {
    'a': 1,  # Ultimo valore di fr ottenuto
    'b': 10e-9,  # Ultimo valore di Qc ottenuto
    'c': 10e-18,       # Impostazione predefinita per c, d, k, phi, Qt, Qc, fr
    'd': 10e-27,
    'k': 2.5,
    'phi': 0.42,
    'Qt': 5000,
    'delta_Q': 1000,
    'fr': 5809178611  # Ultima frequenza di risonanza come valore iniziale
}



fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path, None, None, initial_params=initial_params)
# Out:
# Fit riuscito: False
# Chi quadro ridotto: 53.86153932104904
# fr = 5256019733.679 Hz, Qt = 20362.52, Qc = 35526.82
# a = -4.073e-01 ± 5.859e-07
# b = -2.025e-08 ± 1.013e-12
# c = 5.777e-15 ± 1.305e-18
# d = 1.367e-20 ± 3.444e-23
# k = 1.398e+00 ± 6.358e-07
# phi = -1.196e-01 ± 2.068e-06
# Qt = 2.036e+04 ± 9.326e-02
# delta_Q = 1.516e+04 ± 1.051e-01
# fr = 5.256e+09 ± 8.577e+00

# %% [markdown]
# # FIT TERZA RISONANZA 1.3K -50dBm

# %%
file_path = f"Cavity_resonances_1.3K/res3-50dBm.txt"

initial_params = {
    'a': 1,  # Ultimo valore di fr ottenuto
    'b': 10e-9,  # Ultimo valore di Qc ottenuto
    'c': 10e-18,       # Impostazione predefinita per c, d, k, phi, Qt, Qc, fr
    'd': 10e-27,
    'k': 2.5,
    'phi': 0.42,
    'Qt': 5000,
    'delta_Q': 1000,
    'fr': 5809178611  # Ultima frequenza di risonanza come valore iniziale
}



fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path, None, None, 5.8104e9, 5.8113e9, initial_params=initial_params)
# Out:
# Fit riuscito: True
# Chi quadro ridotto: 66.33105613240654
# fr = 5810770000.002 Hz, Qt = 6120.71, Qc = 7165.06
# a = -8.725e-03 ± 2.083e-06
# b = -4.635e-07 ± 7.651e-12
# c = -4.967e-13 ± 1.994e-17
# d = 8.721e-19 ± 1.031e-21
# k = 1.203e+00 ± 4.455e-06
# phi = 5.526e-02 ± 2.651e-06
# Qt = 6.121e+03 ± 3.977e-02
# delta_Q = 1.044e+03 ± 3.188e-02
# fr = 5.811e+09 ± 1.348e+02

# %% [markdown]
# # FIT QUARTA RISONANZA 1.3K -50dBm

# %%
file_path = f"Cavity_resonances_1.3K/res4-50dBm.txt"



initial_params = {
    'a': 1,  # Ultimo valore di fr ottenuto
    'b': 10e-9,  # Ultimo valore di Qc ottenuto
    'c': 10e-18,       # Impostazione predefinita per c, d, k, phi, Qt, Qc, fr
    'd': 10e-27,
    'k': 1,
    'phi': 0.01,
    'Qt': 5310,
    'delta_Q':1000,
    'fr': 6202500000  # Ultima frequenza di risonanza come valore iniziale
}


fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path,None, None, 6.23425e9, 6.23525e9, initial_params=initial_params)
# Out:
# Fit riuscito: False
# Chi quadro ridotto: 87.3006533459019
# fr = 6234675492.049 Hz, Qt = 5828.53, Qc = 6086.68
# a = 9.562e-02 ± 6.589e-07
# b = -3.789e-07 ± 2.206e-12
# c = -1.461e-12 ± 5.306e-18
# d = 1.402e-18 ± 2.548e-22
# k = 1.574e+00 ± 1.478e-06
# phi = 4.219e-02 ± 5.131e-07
# Qt = 5.829e+03 ± 8.000e-03
# delta_Q = 2.581e+02 ± 9.918e-03
# fr = 6.235e+09 ± 9.111e+00
