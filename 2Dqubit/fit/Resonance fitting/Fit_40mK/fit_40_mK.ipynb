# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
import iminuit as minuit
from iminuit import Minuit
from iminuit.cost import LeastSquares
sys.path.append("..")
import resonance_fit

# %% [markdown]
# # RISONANZA 1 (40mK) al variare della potenza

# %%
fr_list = []
print("-------------------------- -60dBm --------------------------------")
initial_params = {
    'a': 0.02,
    'b': 10e-9,
    'c': 10e-18,
    'd': 10e-27,
    'k': 0.936,
    'phi': 0.083,
    'Qt': 16664,
    'delta_Q': 1000,
    'fr': 4397801533
}
file_path = f"Cavity_resonances_40mK/Res1/risonanza/span_2Mhz/res1-60dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path,initial_params=initial_params)
print(f"Qc = {qc:.2e}, Qt = {qt:.2e}, fr = {fr:.6e} Hz")
Qi= 1/qt - 1/qc
fr_list.append(fr)


print("-------------------------- -55dBm --------------------------------")
initial_params = {
  'a': a,
    'b': b,
    'c': c,
    'd': d,
    'k': k,
    'phi': phi,
    'Qt': qt,
    'delta_Q': 1000,
    'fr': fr
}
file_path = f"Cavity_resonances_40mK/res1/risonanza/span_2Mhz/res1-55dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path, initial_params=initial_params)
print(f"Qc = {qc:.2e}, Qt = {qt:.2e}, fr = {fr:.6e} Hz")
Qi= 1/qt - 1/qc
fr_list.append(fr)


print("-------------------------- -50dBm --------------------------------")
initial_params = {
  'a': a,
    'b': b,
    'c': c,
    'd': d,
    'k': k,
    'phi': phi,
    'Qt': qt,
    'delta_Q': 1000,
    'fr': fr
}
file_path = f"Cavity_resonances_40mK/Res1/risonanza/span_2Mhz/res1-50dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path, initial_params=initial_params)
print(f"Qc = {qc:.2e}, Qt = {qt:.2e}, fr = {fr:.6e} Hz")
Qi= 1/qt - 1/qc
fr_list.append(fr)


print("-------------------------- -45dBm --------------------------------")
initial_params = {
  'a': a,
    'b': b,
    'c': c,
    'd': d,
    'k': k,
    'phi': phi,
    'Qt': qt,
    'delta_Q': 1000,
    'fr': fr
}
file_path = f"Cavity_resonances_40mK/Res1/risonanza/span_2Mhz/res1-45dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path, initial_params=initial_params)
print(f"Qc = {qc:.2e}, Qt = {qt:.2e}, fr = {fr:.6e} Hz")
Qi= 1/qt - 1/qc
fr_list.append(fr)

print("-------------------------- -40dBm --------------------------------")
initial_params = {
  'a': a,
    'b': b,
    'c': c,
    'd': d,
    'k': k,
    'phi': phi,
    'Qt': qt,
    'delta_Q': 1000,
    'fr': fr
}
file_path = f"Cavity_resonances_40mK/Res1/risonanza/span_2Mhz/res1-40dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path,None, None, 4.39525e9, 4.39650e9, initial_params=initial_params)
print(f"Qc = {qc:.2e}, Qt = {qt:.2e}, fr = {fr:.6e} Hz")
Qi= 1/qt - 1/qc
fr_list.append(fr)


print("-------------------------- -35dBm --------------------------------")
initial_params = {
  'a': a,
    'b': b,
    'c': c,
    'd': d,
    'k': k,
    'phi': phi,
    'Qt': qt,
    'delta_Q': 1000,
    'fr': fr
}
file_path = f"Cavity_resonances_40mK/Res1/risonanza/span_2Mhz/res1-35dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path, None, None, 4.39475e9, 4.3965e9, initial_params=initial_params)
print(f"Qc = {qc:.2e}, Qt = {qt:.2e}, fr = {fr:.6e} Hz")
Qi= 1/qt - 1/qc
fr_list.append(fr)
# Out:
# -------------------------- -60dBm --------------------------------
# Fit riuscito: True
# Chi quadro ridotto: 436.61867207551876
# fr = 4395816319.707 Hz, Qt = 17978.48, Qc = 37867.69
# a = -3.174e-01 ± 6.388e-07
# b = -3.825e-09 ± 1.105e-12
# c = 8.205e-15 ± 1.424e-18
# d = 5.525e-21 ± 3.764e-23
# k = 1.261e+00 ± 6.840e-07
# phi = 5.281e-02 ± 3.203e-06
# Qt = 1.798e+04 ± 1.241e-01
# delta_Q = 1.989e+04 ± 1.571e-01
# fr = 4.396e+09 ± 1.238e+01
# Qc = 3.79e+04, Qt = 1.80e+04, fr = 4.395816e+09 Hz
# -------------------------- -55dBm --------------------------------
# Fit riuscito: True
# Chi quadro ridotto: 158.83924440883916
# fr = 4395815348.919 Hz, Qt = 16883.93, Qc = 26660.15
# a = -1.778e-02 ± 6.771e-07
# b = 2.109e-09 ± 1.171e-12
# c = 8.743e-15 ± 1.510e-18
# d = -2.694e-21 ± 3.990e-23
# k = 9.803e-01 ± 7.397e-07
# phi = 4.284e-02 ± 2.996e-06
# Qt = 1.688e+04 ± 1.134e-01
# delta_Q = 9.776e+03 ± 1.241e-01
# fr = 4.396e+09 ± 1.266e+01
# Qc = 2.67e+04, Qt = 1.69e+04, fr = 4.395815e+09 Hz
# -------------------------- -50dBm --------------------------------
# Fit riuscito: True
# Chi quadro ridotto: 50.883268729057995
# fr = 4395812616.743 Hz, Qt = 16703.18, Qc = 24080.83
# a = 5.217e-02 ± 7.906e-07
# b = 2.124e-09 ± 1.368e-12
# c = 8.127e-15 ± 1.764e-18
# d = -3.076e-21 ± 4.662e-23
# k = 9.244e-01 ± 8.684e-07
# phi = 4.672e-02 ± 3.287e-06
# Qt = 1.670e+04 ± 1.243e-01
# delta_Q = 7.378e+03 ± 1.347e-01
# fr = 4.396e+09 ± 1.419e+01
# Qc = 2.41e+04, Qt = 1.67e+04, fr = 4.395813e+09 Hz
# -------------------------- -45dBm --------------------------------
# Fit riuscito: True
# Chi quadro ridotto: 17.537417523512786
# fr = 4395801511.580 Hz, Qt = 16943.85, Qc = 23489.93
# a = 6.100e-02 ± 1.600e-06
# b = 1.324e-08 ± 2.772e-12
# c = 2.452e-15 ± 3.571e-18
# d = -1.078e-20 ± 9.432e-23
# k = 9.340e-01 ± 1.758e-06
# phi = 8.253e-02 ± 6.307e-06
# Qt = 1.694e+04 ± 2.431e-01
# delta_Q = 6.546e+03 ± 2.632e-01
# fr = 4.396e+09 ± 2.698e+01
# Qc = 2.35e+04, Qt = 1.69e+04, fr = 4.395802e+09 Hz
# -------------------------- -40dBm --------------------------------
# Fit riuscito: True
# Chi quadro ridotto: 25.40038601763565
# fr = 4395762524.569 Hz, Qt = 20905.37, Qc = 40300.50
# a = -3.410e-01 ± 4.615e-07
# b = 1.110e-07 ± 1.220e-12
# c = 1.229e-13 ± 2.287e-18
# d = -2.586e-19 ± 8.513e-23
# k = 1.305e+00 ± 5.097e-07
# phi = 2.696e-01 ± 1.775e-06
# Qt = 2.091e+04 ± 7.974e-02
# delta_Q = 1.940e+04 ± 9.281e-02
# fr = 4.396e+09 ± 5.744e+00
# Qc = 4.03e+04, Qt = 2.09e+04, fr = 4.395763e+09 Hz
# -------------------------- -35dBm --------------------------------
# Fit riuscito: True
# Chi quadro ridotto: 462.3727275341123
# fr = 4395675176.797 Hz, Qt = 25833.24, Qc = 75833.24
# a = -1.183e+00 ± 6.895e-07
# b = 9.971e-08 ± 1.405e-12
# c = 9.646e-14 ± 2.131e-18
# d = -9.538e-20 ± 6.617e-23
# k = 2.126e+00 ± 7.147e-07
# phi = 5.171e-01 ± 3.287e-06
# Qt = 2.583e+04 ± 1.775e-01
# delta_Q = 5.000e+04 ± 2.682e-03
# fr = 4.396e+09 ± 8.574e+00
# Qc = 7.58e+04, Qt = 2.58e+04, fr = 4.395675e+09 Hz

# %% [markdown]
# Spostamento della frequenza di risonanza

# %%
fr = inverted_list = [fr_list[i] for i in range(len(fr_list)-1, -1, -1)]
dBm = [-35, -40, -45, -50, -55, -60]

plt.figure(figsize=(8, 5))

plt.plot(fr, dBm, color='lightgray', linewidth=2)
plt.scatter(fr, dBm, color='green', s=50, zorder=3)
plt.xlabel('frequency')
plt.ylabel('power (dBm)')
plt.title('power vs frequency')
plt.grid(True)

plt.show()

# %% [markdown]
# # RISONANZA 2 (40mK) al variare della potenza

# %%
fr_list = []
print("-------------------------- -60dBm --------------------------------")
initial_params = {
    'a': 0.02,
    'b': 10e-9,
    'c': 10e-18,
    'd': 10e-27,
    'k': 0.936,
    'phi': 0.083,
    'Qt': 16664,
    'delta_Q': 1000,
    'fr': 5.256e+09
}
file_path = f"Cavity_resonances_40mK/Res2/risonanza/res2-60dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path, None, None, initial_params=initial_params)
print(f"Qc = {qc:.2e}, Qt = {qt:.2e}, fr = {fr:.6e} Hz")
Qi= 1/qt - 1/qc
fr_list.append(fr)


print("-------------------------- -55dBm --------------------------------")
initial_params = {
  'a': a,
    'b': b,
    'c': c,
    'd': d,
    'k': k,
    'phi': phi,
    'Qt': qt,
    'delta_Q': 1000,
    'fr': fr
}
file_path = f"Cavity_resonances_40mK/res2/risonanza/res2-55dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path, initial_params=initial_params)
print(f"Qc = {qc:.2e}, Qt = {qt:.2e}, fr = {fr:.6e} Hz")
Qi= 1/qt - 1/qc
fr_list.append(fr)


print("-------------------------- -50dBm --------------------------------")
initial_params = {
  'a': a,
    'b': b,
    'c': c,
    'd': d,
    'k': k,
    'phi': phi,
    'Qt': qt,
    'delta_Q': 1000,
    'fr': fr
}
file_path = f"Cavity_resonances_40mK/Res2/risonanza/res2-50dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path, initial_params=initial_params)
print(f"Qc = {qc:.2e}, Qt = {qt:.2e}, fr = {fr:.6e} Hz")
Qi= 1/qt - 1/qc
fr_list.append(fr)


print("-------------------------- -45dBm --------------------------------")
initial_params = {
  'a': a,
    'b': b,
    'c': c,
    'd': d,
    'k': k,
    'phi': phi,
    'Qt': qt,
    'delta_Q': 1000,
    'fr': fr
}
file_path = f"Cavity_resonances_40mK/Res2/risonanza/res2-45dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path, initial_params=initial_params)
print(f"Qc = {qc:.2e}, Qt = {qt:.2e}, fr = {fr:.6e} Hz")
Qi= 1/qt - 1/qc
fr_list.append(fr)

print("-------------------------- -40dBm --------------------------------")
initial_params = {
  'a': a,
    'b': b,
    'c': c,
    'd': d,
    'k': k,
    'phi': phi,
    'Qt': qt,
    'delta_Q': 1000,
    'fr': fr
}
file_path = f"Cavity_resonances_40mK/Res2/risonanza/res2-40dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path, initial_params=initial_params)
print(f"Qc = {qc:.2e}, Qt = {qt:.2e}, fr = {fr:.6e} Hz")
Qi= 1/qt - 1/qc
fr_list.append(fr)


print("-------------------------- -35dBm --------------------------------")
initial_params = {
  'a': a,
    'b': b,
    'c': c,
    'd': d,
    'k': k,
    'phi': phi,
    'Qt': qt,
    'delta_Q': 1000,
    'fr': fr
}
file_path = f"Cavity_resonances_40mK/Res2/risonanza/res2-35dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path, None, None, initial_params=initial_params)
print(f"Qc = {qc:.2e}, Qt = {qt:.2e}, fr = {fr:.6e} Hz")
Qi= 1/qt - 1/qc
fr_list.append(fr)
# Out:
# -------------------------- -60dBm --------------------------------
# Fit riuscito: True
# Chi quadro ridotto: 565.9659868377822
# fr = 5257113879.935 Hz, Qt = 14953.60, Qc = 19623.26
# a = 8.890e-02 ± 5.917e-07
# b = -8.269e-09 ± 1.023e-12
# c = -5.627e-15 ± 1.319e-18
# d = 4.822e-21 ± 3.485e-23
# k = 8.456e-01 ± 6.745e-07
# phi = -8.018e-02 ± 2.098e-06
# Qt = 1.495e+04 ± 7.073e-02
# delta_Q = 4.670e+03 ± 7.768e-02
# fr = 5.257e+09 ± 1.206e+01
# Qc = 1.96e+04, Qt = 1.50e+04, fr = 5.257114e+09 Hz
# -------------------------- -55dBm --------------------------------
# Fit riuscito: True
# Chi quadro ridotto: 200.54270519084065
# fr = 5257107849.528 Hz, Qt = 16016.51, Qc = 23941.48
# a = -3.130e-02 ± 8.097e-07
# b = -4.263e-09 ± 1.401e-12
# c = 4.903e-15 ± 1.806e-18
# d = 2.516e-21 ± 4.775e-23
# k = 1.006e+00 ± 9.082e-07
# phi = -5.704e-02 ± 2.948e-06
# Qt = 1.602e+04 ± 1.051e-01
# delta_Q = 7.925e+03 ± 1.137e-01
# fr = 5.257e+09 ± 1.556e+01
# Qc = 2.39e+04, Qt = 1.60e+04, fr = 5.257108e+09 Hz
# -------------------------- -50dBm --------------------------------
# Fit riuscito: True
# Chi quadro ridotto: 61.440833853539296
# fr = 5257107641.625 Hz, Qt = 15855.33, Qc = 22414.86
# a = 1.264e-02 ± 8.327e-07
# b = -3.635e-09 ± 1.441e-12
# c = 5.811e-17 ± 1.858e-18
# d = 6.368e-22 ± 4.911e-23
# k = 9.767e-01 ± 9.384e-07
# phi = -5.871e-02 ± 2.892e-06
# Qt = 1.586e+04 ± 1.026e-01
# delta_Q = 6.560e+03 ± 1.110e-01
# fr = 5.257e+09 ± 1.554e+01
# Qc = 2.24e+04, Qt = 1.59e+04, fr = 5.257108e+09 Hz
# -------------------------- -45dBm --------------------------------
# Fit riuscito: True
# Chi quadro ridotto: 20.76705057292241
# fr = 5257104058.466 Hz, Qt = 16044.29, Qc = 21969.99
# a = 2.830e-02 ± 1.164e-06
# b = 1.271e-09 ± 2.016e-12
# c = -3.623e-16 ± 2.598e-18
# d = -3.994e-21 ± 6.867e-23
# k = 9.713e-01 ± 1.313e-06
# phi = -4.989e-02 ± 3.918e-06
# Qt = 1.604e+04 ± 1.414e-01
# delta_Q = 5.926e+03 ± 1.540e-01
# fr = 5.257e+09 ± 2.092e+01
# Qc = 2.20e+04, Qt = 1.60e+04, fr = 5.257104e+09 Hz
# -------------------------- -40dBm --------------------------------
# Fit riuscito: True
# Chi quadro ridotto: 8.895945764943537
# fr = 5257087929.639 Hz, Qt = 16347.08, Qc = 21315.24
# a = 5.142e-02 ± 6.913e-07
# b = 1.732e-08 ± 1.196e-12
# c = 3.065e-15 ± 1.542e-18
# d = -1.758e-20 ± 4.073e-23
# k = 9.502e-01 ± 7.799e-07
# phi = -7.843e-03 ± 2.242e-06
# Qt = 1.635e+04 ± 8.332e-02
# delta_Q = 4.968e+03 ± 9.258e-02
# fr = 5.257e+09 ± 1.186e+01
# Qc = 2.13e+04, Qt = 1.63e+04, fr = 5.257088e+09 Hz
# -------------------------- -35dBm --------------------------------
# Fit riuscito: True
# Chi quadro ridotto: 37.964992276060606
# fr = 5257038391.831 Hz, Qt = 17498.05, Qc = 22699.98
# a = 3.191e-02 ± 3.180e-07
# b = 6.203e-08 ± 5.471e-13
# c = 1.785e-14 ± 6.965e-19
# d = -5.550e-20 ± 1.806e-23
# k = 9.614e-01 ± 3.558e-07
# phi = 1.136e-01 ± 1.047e-06
# Qt = 1.750e+04 ± 4.186e-02
# delta_Q = 5.202e+03 ± 4.565e-02
# fr = 5.257e+09 ± 5.181e+00
# Qc = 2.27e+04, Qt = 1.75e+04, fr = 5.257038e+09 Hz

# %% [markdown]
# Spostamento della frequenza di risonanza

# %%
fr = inverted_list = [fr_list[i] for i in range(len(fr_list)-1, -1, -1)]
dBm = [-35, -40, -45, -50, -55, -60]

plt.figure(figsize=(8, 5))

plt.plot(fr, dBm, color='lightgray', linewidth=2)
plt.scatter(fr, dBm, color='green', s=50, zorder=3)
plt.xlabel('frequency')
plt.ylabel('power (dBm)')
plt.title('power vs frequency')
plt.grid(True)

plt.show()

# %% [markdown]
# # RISONANZA 3 (40mK) al variare della potenza

# %%
fr_list = []

# -60 dBm
print("-------------------------- -60dBm --------------------------------")
initial_params = {
    'a': 0.02, 'b': 10e-9, 'c': 10e-18, 'd': 10e-27,
    'k': 0.936, 'phi': 0.083, 'Qt': 16664,
    'delta_Q': 1000, 'fr': 4395801533
}
file_path = f"Cavity_resonances_40mK/Res3/risonanza/res3-60dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(
    file_path, None, None, 5.8115e9, 5.8125e9, initial_params=initial_params)
print(f"Qc = {qc:.2e}, Qt = {qt:.2e}, fr = {fr:.6e} Hz")
Qi = 1/qt - 1/qc
fr_list.append(fr)

initial_params = {'fr': fr, 'a': a, 'b': b, 'c': c, 'd': d,
                  'k': k, 'phi': phi, 'Qt': qt, 'delta_Q': 1000}

# -55 dBm
print("-------------------------- -55dBm --------------------------------")
file_path = f"Cavity_resonances_40mK/Res3/risonanza/res3-55dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(
    file_path, None, None, 5.8114e9, 5.8123e9, initial_params=initial_params)
print(f"Qc = {qc:.2e}, Qt = {qt:.2e}, fr = {fr:.6e} Hz")
Qi = 1/qt - 1/qc
fr_list.append(fr)

initial_params = {'fr': fr, 'a': a, 'b': b, 'c': c, 'd': d,
                  'k': k, 'phi': phi, 'Qt': qt, 'delta_Q': 1000}

# -50 dBm
print("-------------------------- -50dBm --------------------------------")
file_path = f"Cavity_resonances_40mK/Res3/risonanza/res3-50dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(
    file_path, None, None, 5.8118e9, 5.8126e9, initial_params=initial_params)
print(f"Qc = {qc:.2e}, Qt = {qt:.2e}, fr = {fr:.6e} Hz")
Qi = 1/qt - 1/qc
fr_list.append(fr)

initial_params = {'fr': fr, 'a': a, 'b': b, 'c': c, 'd': d,
                  'k': k, 'phi': phi, 'Qt': qt, 'delta_Q': 1000}

# -45 dBm
print("-------------------------- -45dBm --------------------------------")
file_path = f"Cavity_resonances_40mK/Res3/risonanza/res3-45dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(
    file_path, None, None, 5.8117e9, 5.8123e9, initial_params=initial_params)
print(f"Qc = {qc:.2e}, Qt = {qt:.2e}, fr = {fr:.6e} Hz")
Qi = 1/qt - 1/qc
fr_list.append(fr)

initial_params = {'fr': fr, 'a': a, 'b': b, 'c': c, 'd': d,
                  'k': k, 'phi': phi, 'Qt': qt, 'delta_Q': 1000}

# -40 dBm
print("-------------------------- -40dBm --------------------------------")
file_path = f"Cavity_resonances_40mK/Res3/risonanza/res3-40dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(
    file_path, None, None, 5.8116e9, 5.8122e9, initial_params=initial_params)
print(f"Qc = {qc:.2e}, Qt = {qt:.2e}, fr = {fr:.6e} Hz")
Qi = 1/qt - 1/qc
fr_list.append(fr)

initial_params = {'fr': fr, 'a': a, 'b': b, 'c': c, 'd': d,
                  'k': k, 'phi': phi, 'Qt': qt, 'delta_Q': 1000}

# -35 dBm
print("-------------------------- -35dBm --------------------------------")
file_path = f"Cavity_resonances_40mK/Res3/risonanza/res3-35dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(
    file_path, None, None, 5.8116e9, 5.8122e9, initial_params=initial_params)
print(f"Qc = {qc:.2e}, Qt = {qt:.2e}, fr = {fr:.6e} Hz")
Qi = 1/qt - 1/qc
fr_list.append(fr)
# Out:
# -------------------------- -60dBm --------------------------------
# Fit riuscito: False
# Chi quadro ridotto: 705.5285223516513
# fr = 5811941525.109 Hz, Qt = 7828.36, Qc = 9695.40
# a = -2.604e-02 ± 1.311e-06
# b = -4.944e-07 ± 4.453e-12
# c = 5.006e-14 ± 1.100e-17
# d = 7.621e-19 ± 5.461e-22
# k = 9.310e-01 ± 2.259e-06
# phi = -3.492e-03 ± 2.458e-06
# Qt = 7.828e+03 ± 4.276e-02
# delta_Q = 1.867e+03 ± 3.930e-02
# fr = 5.812e+09 ± 2.248e+01
# Qc = 9.70e+03, Qt = 7.83e+03, fr = 5.811942e+09 Hz
# -------------------------- -55dBm --------------------------------
# Fit riuscito: False
# Chi quadro ridotto: 272.33193019414557
# fr = 5811898096.802 Hz, Qt = 8711.88, Qc = 11816.75
# a = -7.208e-02 ± 1.279e-06
# b = -4.088e-07 ± 4.814e-12
# c = 4.952e-14 ± 1.323e-17
# d = 7.941e-19 ± 7.332e-22
# k = 9.652e-01 ± 2.063e-06
# phi = 1.551e-01 ± 2.671e-06
# Qt = 8.712e+03 ± 5.174e-02
# delta_Q = 3.105e+03 ± 4.383e-02
# fr = 5.812e+09 ± 2.112e+01
# Qc = 1.18e+04, Qt = 8.71e+03, fr = 5.811898e+09 Hz
# -------------------------- -50dBm --------------------------------
# Fit riuscito: False
# Chi quadro ridotto: 83.0117797781897
# fr = 5811921846.687 Hz, Qt = 8045.52, Qc = 9747.87
# a = 3.125e-02 ± 6.551e-07
# b = -3.998e-07 ± 1.807e-12
# c = 6.903e-13 ± 3.438e-18
# d = -3.202e-19 ± 1.338e-22
# k = 8.045e-01 ± 1.106e-06
# phi = 7.018e-02 ± 1.500e-06
# Qt = 8.046e+03 ± 2.686e-02
# delta_Q = 1.702e+03 ± 2.137e-02
# fr = 5.812e+09 ± 1.323e+01
# Qc = 9.75e+03, Qt = 8.05e+03, fr = 5.811922e+09 Hz
# -------------------------- -45dBm --------------------------------
# Fit riuscito: True
# Chi quadro ridotto: 30.693158777080562
# fr = 5811918120.973 Hz, Qt = 9299.03, Qc = 12539.89
# a = -6.884e-02 ± 1.743e-06
# b = -4.279e-07 ± 9.039e-12
# c = 4.213e-13 ± 3.212e-17
# d = 3.444e-19 ± 2.257e-21
# k = 9.032e-01 ± 3.407e-06
# phi = 9.527e-02 ± 3.858e-06
# Qt = 9.299e+03 ± 8.423e-02
# delta_Q = 3.241e+03 ± 5.760e-02
# fr = 5.812e+09 ± 2.507e+01
# Qc = 1.25e+04, Qt = 9.30e+03, fr = 5.811918e+09 Hz
# -------------------------- -40dBm --------------------------------
# Fit riuscito: True
# Chi quadro ridotto: 8.2564896097762
# fr = 5811908079.370 Hz, Qt = 6031.37, Qc = 7172.37
# a = -6.218e-02 ± 5.031e-06
# b = -3.919e-07 ± 2.896e-11
# c = -9.911e-13 ± 1.225e-16
# d = 2.927e-19 ± 1.066e-20
# k = 1.412e+00 ± 1.372e-05
# phi = 6.760e-02 ± 5.630e-06
# Qt = 6.031e+03 ± 1.033e-01
# delta_Q = 1.141e+03 ± 5.375e-02
# fr = 5.812e+09 ± 6.699e+01
# Qc = 7.17e+03, Qt = 6.03e+03, fr = 5.811908e+09 Hz
# -------------------------- -35dBm --------------------------------
# Fit riuscito: False
# Chi quadro ridotto: 4.963545997695099
# fr = 5811875301.166 Hz, Qt = 5824.16, Qc = 6815.61
# a = -4.715e-02 ± 2.973e-06
# b = -3.911e-07 ± 1.685e-11
# c = -8.175e-13 ± 7.034e-17
# d = 4.187e-19 ± 5.949e-21
# k = 1.409e+00 ± 8.494e-06
# phi = 9.622e-02 ± 3.223e-06
# Qt = 5.824e+03 ± 5.877e-02
# delta_Q = 9.914e+02 ± 3.017e-02
# fr = 5.812e+09 ± 3.848e+01
# Qc = 6.82e+03, Qt = 5.82e+03, fr = 5.811875e+09 Hz

# %% [markdown]
# Spostamento frequenza di risonanza

# %%
fr = inverted_list = [fr_list[i] for i in range(len(fr_list)-1, -1, -1)]
dBm = [-35, -40, -45, -50, -55, -60]

plt.figure(figsize=(8, 5))

plt.plot(fr, dBm, color='lightgray', linewidth=2)
plt.scatter(fr, dBm, color='green', s=50, zorder=3)
plt.xlabel('frequency')
plt.ylabel('power (dBm)')
plt.title('power vs frequency')
plt.grid(True)

plt.show()

# %% [markdown]
# # RISONANZA 4 (40mK) al variare della potenza

# %%
fr_list = []

# -60 dBm
print("-------------------------- -60dBm --------------------------------")
initial_params = {
    'a': 0.02, 'b': 10e-9, 'c': 10e-18, 'd': 10e-27,
    'k': 0.936, 'phi': 0.083, 'Qt': 10000,
    'delta_Q': 1000, 'fr': 6.235e9
}
file_path = f"Cavity_resonances_40mK/Res4/risonanza/res4-60dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(
    file_path, None, None, 6.234e9, 6.238e9, initial_params=initial_params)
print(f"Qc = {qc:.2e}, Qt = {qt:.2e}, fr = {fr:.6e} Hz")
Qi = 1/qt - 1/qc
fr_list.append(fr)

# Aggiorna tutti i parametri
initial_params = {'fr': fr, 'a': a, 'b': b, 'c': c, 'd': d, 'k': k, 'phi': phi, 'Qt': qt + 5000, 'delta_Q': 1000}

# -55 dBm
print("-------------------------- -55dBm --------------------------------")
file_path = f"Cavity_resonances_40mK/Res4/risonanza/res4-55dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(
    file_path, None, None, 6.234e9, 6.238e9, initial_params=initial_params)
print(f"Qc = {qc:.2e}, Qt = {qt:.2e}, fr = {fr:.6e} Hz")
Qi = 1/qt - 1/qc
fr_list.append(fr)
initial_params = {'fr': fr, 'a': a, 'b': b, 'c': c, 'd': d, 'k': k, 'phi': phi, 'Qt': qt, 'delta_Q': 1000}

# -50 dBm
print("-------------------------- -50dBm --------------------------------")
file_path = f"Cavity_resonances_40mK/Res4/risonanza/res4-50dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(
    file_path, None, None, 6.234e9, 6.238e9, initial_params=initial_params)
print(f"Qc = {qc:.2e}, Qt = {qt:.2e}, fr = {fr:.6e} Hz")
Qi = 1/qt - 1/qc
fr_list.append(fr)
initial_params = {'fr': fr, 'a': a, 'b': b, 'c': c, 'd': d, 'k': k, 'phi': phi, 'Qt': qt, 'delta_Q': 1000}

# -45 dBm
print("-------------------------- -45dBm --------------------------------")
file_path = f"Cavity_resonances_40mK/Res4/risonanza/res4-45dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(
    file_path, None, None, 6.234e9, 6.238e9, initial_params=initial_params)
print(f"Qc = {qc:.2e}, Qt = {qt:.2e}, fr = {fr:.6e} Hz")
Qi = 1/qt - 1/qc
fr_list.append(fr)
initial_params = {'fr': fr, 'a': a, 'b': b, 'c': c, 'd': d, 'k': k, 'phi': phi, 'Qt': qt, 'delta_Q': 1000}

# -40 dBm
print("-------------------------- -40dBm --------------------------------")
file_path = f"Cavity_resonances_40mK/Res4/risonanza/res4-40dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(
    file_path, None, None, 6.234e9, 6.238e9, initial_params=initial_params)
print(f"Qc = {qc:.2e}, Qt = {qt:.2e}, fr = {fr:.6e} Hz")
Qi = 1/qt - 1/qc
fr_list.append(fr)
initial_params = {'fr': fr, 'a': a, 'b': b, 'c': c, 'd': d, 'k': k, 'phi': phi, 'Qt': qt, 'delta_Q': 1000}

# -35 dBm
print("-------------------------- -35dBm --------------------------------")
file_path = f"Cavity_resonances_40mK/Res4/risonanza/res4-35dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(
    file_path, None, None, 6.234e9, 6.238e9, initial_params=initial_params)
print(f"Qc = {qc:.2e}, Qt = {qt:.2e}, fr = {fr:.6e} Hz")
Qi = 1/qt - 1/qc
fr_list.append(fr)
# Out:
# -------------------------- -60dBm --------------------------------
# Fit riuscito: False
# Chi quadro ridotto: 634.0419980565532
# fr = 6235785000.379 Hz, Qt = 13399.31, Qc = 61026.49
# a = -2.331e+00 ± 8.910e-07
# b = -1.485e-08 ± 7.577e-13
# c = -3.209e-15 ± 4.703e-19
# d = 5.700e-21 ± 5.882e-24
# k = 3.257e+00 ± 9.210e-07
# phi = 3.095e-01 ± 4.168e-06
# Qt = 1.340e+04 ± 9.869e-02
# delta_Q = 4.763e+04 ± 2.694e-01
# fr = 6.236e+09 ± 4.165e-01
# Qc = 6.10e+04, Qt = 1.34e+04, fr = 6.235785e+09 Hz
# -------------------------- -55dBm --------------------------------
# Fit riuscito: True
# Chi quadro ridotto: 214.4971567383146
# fr = 6235767874.392 Hz, Qt = 13753.29, Qc = 61066.19
# a = -2.293e+00 ± 9.490e-08
# b = -1.567e-09 ± 8.048e-14
# c = 4.409e-16 ± 4.967e-20
# d = 1.706e-21 ± 6.164e-25
# k = 3.218e+00 ± 9.803e-08
# phi = 3.786e-01 ± 4.418e-07
# Qt = 1.375e+04 ± 1.085e-02
# delta_Q = 4.731e+04 ± 2.881e-02
# fr = 6.236e+09 ± 3.046e+00
# Qc = 6.11e+04, Qt = 1.38e+04, fr = 6.235768e+09 Hz
# -------------------------- -50dBm --------------------------------
# Fit riuscito: True
# Chi quadro ridotto: 91.66455065325415
# fr = 6235765000.000 Hz, Qt = 13776.48, Qc = 58134.17
# a = -2.207e+00 ± 2.079e-06
# b = -5.957e-10 ± 1.766e-12
# c = 8.240e-16 ± 1.087e-18
# d = 1.320e-21 ± 1.344e-23
# k = 3.150e+00 ± 2.151e-06
# phi = 3.848e-01 ± 9.371e-06
# Qt = 1.378e+04 ± 2.331e-01
# delta_Q = 4.436e+04 ± 5.860e-01
# fr = 6.236e+09 ± 6.874e+00
# Qc = 5.81e+04, Qt = 1.38e+04, fr = 6.235765e+09 Hz
# -------------------------- -45dBm --------------------------------
# Fit riuscito: True
# Chi quadro ridotto: 37.064684660893846
# fr = 6235761566.142 Hz, Qt = 14035.69, Qc = 56982.68
# a = -2.132e+00 ± 9.663e-08
# b = 2.909e-10 ± 8.186e-14
# c = 1.803e-15 ± 5.041e-20
# d = 1.280e-21 ± 6.237e-25
# k = 3.083e+00 ± 1.000e-07
# phi = 3.946e-01 ± 4.305e-07
# Qt = 1.404e+04 ± 1.104e-02
# delta_Q = 4.295e+04 ± 2.658e-02
# fr = 6.236e+09 ± 2.924e+00
# Qc = 5.70e+04, Qt = 1.40e+04, fr = 6.235762e+09 Hz
# -------------------------- -40dBm --------------------------------
# Fit riuscito: True
# Chi quadro ridotto: 20.86528132266991
# fr = 6235752759.998 Hz, Qt = 14168.28, Qc = 55198.95
# a = -2.066e+00 ± 9.646e-08
# b = 1.606e-09 ± 8.159e-14
# c = 1.427e-15 ± 5.008e-20
# d = 1.173e-21 ± 6.171e-25
# k = 3.023e+00 ± 9.991e-08
# phi = 4.042e-01 ± 4.211e-07
# Qt = 1.417e+04 ± 1.103e-02
# delta_Q = 4.103e+04 ± 2.535e-02
# fr = 6.236e+09 ± 2.841e+00
# Qc = 5.52e+04, Qt = 1.42e+04, fr = 6.235753e+09 Hz
# -------------------------- -35dBm --------------------------------
# Fit riuscito: False
# Chi quadro ridotto: 13.577687645887087
# fr = 6235730000.014 Hz, Qt = 14486.93, Qc = 64477.74
# a = -2.583e+00 ± 1.347e-06
# b = 4.568e-09 ± 1.135e-12
# c = 2.301e-15 ± 6.904e-19
# d = 4.291e-22 ± 8.405e-24
# k = 3.541e+00 ± 1.388e-06
# phi = 4.298e-01 ± 5.841e-06
# Qt = 1.449e+04 ± 1.511e-01
# delta_Q = 4.999e+04 ± 3.778e-01
# fr = 6.236e+09 ± 1.208e+00
# Qc = 6.45e+04, Qt = 1.45e+04, fr = 6.235730e+09 Hz

# %% [markdown]
# Spostamento frequenza di risonanza

# %%
fr = inverted_list = [fr_list[i] for i in range(len(fr_list)-1, -1, -1)]
dBm = [-35, -40, -45, -50, -55, -60]

plt.figure(figsize=(8, 5))

plt.plot(fr, dBm, color='lightgray', linewidth=2)
plt.scatter(fr, dBm, color='green', s=50, zorder=3)
plt.xlabel('frequency')
plt.ylabel('power (dBm)')
plt.title('power vs frequency')
plt.grid(True)

plt.show()
