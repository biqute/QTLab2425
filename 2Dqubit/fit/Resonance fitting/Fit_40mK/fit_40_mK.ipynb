# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
import iminuit as minuit
from iminuit import Minuit
from iminuit.cost import LeastSquares
sys.path.append("..")
import resonance_fit

# %% [markdown]
# # RISONANZA 1 (40mK) al variare della potenza

# %%
fr_list = []
print("-------------------------- -60dBm --------------------------------")
initial_params = {
    'a': 0.02,
    'b': 10e-9,
    'c': 10e-18,
    'd': 10e-27,
    'k': 0.936,
    'phi': 0.083,
    'Qt': 16664,
    'delta_Q': 1000,
    'fr': 4395801533
}
file_path = f"Cavity_resonances_40mK/Res1/risonanza/span_2Mhz/res1-60dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path,initial_params=initial_params)
print(f"Qc = {qc:.2e}, Qt = {qt:.2e}, fr = {fr:.6e} Hz")
Qi= 1/qt - 1/qc
fr_list.append(fr)


print("-------------------------- -55dBm --------------------------------")
initial_params = {
  'a': 0.02,
    'b': 10e-9,
    'c': 10e-18,
    'd': 10e-27,
    'k': 0.936,
    'phi': 0.083,
    'Qt': 16664,
    'delta_Q': 1000,
    'fr': fr
}
file_path = f"Cavity_resonances_40mK/res1/risonanza/span_2Mhz/res1-55dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path, initial_params=initial_params)
print(f"Qc = {qc:.2e}, Qt = {qt:.2e}, fr = {fr:.6e} Hz")
Qi= 1/qt - 1/qc
fr_list.append(fr)


print("-------------------------- -50dBm --------------------------------")
initial_params = {
    'a': 0.02,
    'b': 10e-9,
    'c': 10e-18,
    'd': 10e-27,
    'k': 0.936,
    'phi': 0.083,
    'Qt': 16664,
    'delta_Q': 1000,
    'fr': fr
}
file_path = f"Cavity_resonances_40mK/Res1/risonanza/span_2Mhz/res1-50dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path, initial_params=initial_params)
print(f"Qc = {qc:.2e}, Qt = {qt:.2e}, fr = {fr:.6e} Hz")
Qi= 1/qt - 1/qc
fr_list.append(fr)


print("-------------------------- -45dBm --------------------------------")
initial_params = {
    'a': 0.02,
    'b': 10e-9,
    'c': 10e-18,
    'd': 10e-27,
    'k': 0.936,
    'phi': 0.083,
    'Qt': 16664,
    'delta_Q': 1000,
    'fr': fr
}
file_path = f"Cavity_resonances_40mK/Res1/risonanza/span_2Mhz/res1-45dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path, initial_params=initial_params)
print(f"Qc = {qc:.2e}, Qt = {qt:.2e}, fr = {fr:.6e} Hz")
Qi= 1/qt - 1/qc
fr_list.append(fr)

print("-------------------------- -40dBm --------------------------------")
initial_params = {
      'a': 0.02,
    'b': 10e-9,
    'c': 10e-18,
    'd': 10e-27,
    'k': 0.936,
    'phi': 0.083,
    'Qt': 16664,
    'delta_Q': 1000,
    'fr': fr
}
file_path = f"Cavity_resonances_40mK/Res1/risonanza/span_2Mhz/res1-40dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path,None, None, 4.39525e9, 4.39650e9, initial_params=initial_params)
print(f"Qc = {qc:.2e}, Qt = {qt:.2e}, fr = {fr:.6e} Hz")
Qi= 1/qt - 1/qc
fr_list.append(fr)


print("-------------------------- -35dBm --------------------------------")
initial_params = {
    'a': 0.02,
    'b': 10e-9,
    'c': 10e-18,
    'd': 10e-27,
    'k': 0.936,
    'phi': 0.3,
    'Qt': 10000,
    'delta_Q': 1000,
    'fr': fr
}
file_path = f"Cavity_resonances_40mK/Res1/risonanza/span_2Mhz/res1-35dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path, None, None, 4.39555e9, 4.3960e9, initial_params=initial_params)
print(f"Qc = {qc:.2e}, Qt = {qt:.2e}, fr = {fr:.6e} Hz")
Qi= 1/qt - 1/qc
fr_list.append(fr)
# Out:
# -------------------------- -60dBm --------------------------------
# Fit riuscito: True
# Chi quadro ridotto: 436.6186719519964
# fr = 4395816319.924 Hz, Qt = 17978.97, Qc = 37874.33
# a = -3.176e-01 ± 6.388e-07
# b = -3.825e-09 ± 1.105e-12
# c = 8.205e-15 ± 1.424e-18
# d = 5.525e-21 ± 3.764e-23
# k = 1.262e+00 ± 6.840e-07
# phi = 5.281e-02 ± 3.203e-06
# Qt = 1.798e+04 ± 1.241e-01
# delta_Q = 1.990e+04 ± 1.571e-01
# fr = 4.396e+09 ± 1.238e+01
# c:\Users\franc\OneDrive\Desktop\QTLab2425\2Dqubit\fit\Resonance fitting\Fit_40mK\..\resonance_fit.py:193: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# Qc = 3.79e+04, Qt = 1.80e+04, fr = 4.395816e+09 Hz
# -------------------------- -55dBm --------------------------------
# Fit riuscito: True
# Chi quadro ridotto: 158.83924442394414
# fr = 4395815348.577 Hz, Qt = 16883.57, Qc = 26657.84
# a = -1.772e-02 ± 6.771e-07
# b = 2.110e-09 ± 1.172e-12
# ...

# %% [markdown]
# Spostamento della frequenza di risonanza

# %%
fr = inverted_list = [fr_list[i] for i in range(len(fr_list)-1, -1, -1)]
dBm = [-35, -40, -45, -50, -55, -60]

plt.figure(figsize=(8, 5))

plt.plot(fr, dBm, color='lightgray', linewidth=2)
plt.scatter(fr, dBm, color='green', s=50, zorder=3)
plt.xlabel('frequency')
plt.ylabel('power (dBm)')
plt.title('power vs frequency')
plt.grid(True)

plt.show()

# %% [markdown]
# # RISONANZA 2 (40mK) al variare della potenza

# %%
fr_list = []
print("-------------------------- -60dBm --------------------------------")
initial_params = {
    'a': 0.02,
    'b': 10e-9,
    'c': 10e-18,
    'd': 10e-27,
    'k': 0.936,
    'phi': 0.083,
    'Qt': 16664,
    'delta_Q': 1000,
    'fr': 5.256e+09
}
file_path = f"Cavity_resonances_40mK/Res2/risonanza/res2-60dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path, None, None, 5.2565e9, 5.2573e9, initial_params=initial_params)
print(f"Qc = {qc:.2e}, Qt = {qt:.2e}, fr = {fr:.6e} Hz")
Qi= 1/qt - 1/qc
fr_list.append(fr)


print("-------------------------- -55dBm --------------------------------")
initial_params = {
  'a': 0.02,
    'b': 10e-9,
    'c': 10e-18,
    'd': 10e-27,
    'k': 0.936,
    'phi': 0.083,
    'Qt': 16664,
    'delta_Q': 1000,
    'fr': fr
}
file_path = f"Cavity_resonances_40mK/res2/risonanza/res2-55dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path, initial_params=initial_params)
print(f"Qc = {qc:.2e}, Qt = {qt:.2e}, fr = {fr:.6e} Hz")
Qi= 1/qt - 1/qc
fr_list.append(fr)


print("-------------------------- -50dBm --------------------------------")
initial_params = {
    'a': 0.02,
    'b': 10e-9,
    'c': 10e-18,
    'd': 10e-27,
    'k': 0.936,
    'phi': 0.083,
    'Qt': 16664,
    'delta_Q': 1000,
    'fr': fr
}
file_path = f"Cavity_resonances_40mK/Res2/risonanza/res2-50dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path, initial_params=initial_params)
print(f"Qc = {qc:.2e}, Qt = {qt:.2e}, fr = {fr:.6e} Hz")
Qi= 1/qt - 1/qc
fr_list.append(fr)


print("-------------------------- -45dBm --------------------------------")
initial_params = {
    'a': 0.02,
    'b': 10e-9,
    'c': 10e-18,
    'd': 10e-27,
    'k': 0.936,
    'phi': 0.083,
    'Qt': 16664,
    'delta_Q': 1000,
    'fr': fr
}
file_path = f"Cavity_resonances_40mK/Res2/risonanza/res2-45dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path, initial_params=initial_params)
print(f"Qc = {qc:.2e}, Qt = {qt:.2e}, fr = {fr:.6e} Hz")
Qi= 1/qt - 1/qc
fr_list.append(fr)

print("-------------------------- -40dBm --------------------------------")
initial_params = {
      'a': 0.02,
    'b': 10e-9,
    'c': 10e-18,
    'd': 10e-27,
    'k': 0.936,
    'phi': 0.083,
    'Qt': 16664,
    'delta_Q': 1000,
    'fr': fr
}
file_path = f"Cavity_resonances_40mK/Res2/risonanza/res2-40dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path, initial_params=initial_params)
print(f"Qc = {qc:.2e}, Qt = {qt:.2e}, fr = {fr:.6e} Hz")
Qi= 1/qt - 1/qc
fr_list.append(fr)


print("-------------------------- -35dBm --------------------------------")
initial_params = {
    'a': 0.02,
    'b': 10e-9,
    'c': 10e-18,
    'd': 10e-27,
    'k': 0.936,
    'phi': 0.083,
    'Qt': 16664,
    'delta_Q': 1000,
    'fr': fr
}
file_path = f"Cavity_resonances_40mK/Res2/risonanza/res2-35dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path, None, None, 5.2565e9, 5.2575e9, initial_params=initial_params)
print(f"Qc = {qc:.2e}, Qt = {qt:.2e}, fr = {fr:.6e} Hz")
Qi= 1/qt - 1/qc
fr_list.append(fr)
# Out:
# -------------------------- -60dBm --------------------------------
# ✅ Fit riuscito: False
# 📉 Chi quadro ridotto: 575.9790700995882
# fr = 5257147793.846 Hz, Qt = 12477.63, Qc = 14534.96
# a = 1.238e-01 ± 5.563e-07
# b = -3.740e-07 ± 1.641e-12
# c = -1.582e-12 ± 3.285e-18
# d = -1.379e-18 ± 1.341e-22
# k = 9.261e-01 ± 8.461e-07
# phi = -2.562e-01 ± 1.156e-06
# Qt = 1.248e+04 ± 2.993e-02
# delta_Q = 2.057e+03 ± 2.834e-02
# fr = 5.257e+09 ± 6.986e+00
# Qc = 1.45e+04, Qt = 1.25e+04, fr = 5.257148e+09 Hz
# -------------------------- -55dBm --------------------------------
# ✅ Fit riuscito: True
# 📉 Chi quadro ridotto: 200.54270515296506
# fr = 5257107849.791 Hz, Qt = 16016.53, Qc = 23941.57
# a = -3.131e-02 ± 8.097e-07
# b = -4.264e-09 ± 1.401e-12
# c = 4.903e-15 ± 1.806e-18
# d = 2.517e-21 ± 4.775e-23
# k = 1.006e+00 ± 9.082e-07
# phi = -5.705e-02 ± 2.948e-06
# Qt = 1.602e+04 ± 1.051e-01
# delta_Q = 7.925e+03 ± 1.137e-01
# fr = 5.257e+09 ± 1.556e+01
# ...

# %% [markdown]
# Spostamento della frequenza di risonanza

# %%
fr = inverted_list = [fr_list[i] for i in range(len(fr_list)-1, -1, -1)]
dBm = [-35, -40, -45, -50, -55, -60]

plt.figure(figsize=(8, 5))

plt.plot(fr, dBm, color='lightgray', linewidth=2)
plt.scatter(fr, dBm, color='green', s=50, zorder=3)
plt.xlabel('frequency')
plt.ylabel('power (dBm)')
plt.title('power vs frequency')
plt.grid(True)

plt.show()

# %% [markdown]
# # RISONANZA 3 (40mK) al variare della potenza

# %%
fr_list = []

# -60 dBm
print("-------------------------- -60dBm --------------------------------")
initial_params = {
    'a': 0.02, 'b': 10e-9, 'c': 10e-18, 'd': 10e-27,
    'k': 0.936, 'phi': 0.083, 'Qt': 16664,
    'delta_Q': 1000, 'fr': 4395801533
}
file_path = f"Cavity_resonances_40mK/Res3/risonanza/res3-60dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(
    file_path, None, None, 5.8115e9, 5.8125e9, initial_params=initial_params)
print(f"Qc = {qc:.2e}, Qt = {qt:.2e}, fr = {fr:.6e} Hz")
Qi = 1/qt - 1/qc
fr_list.append(fr)

initial_params = {'fr': fr, 'a': a, 'b': b, 'c': c, 'd': d,
                  'k': k, 'phi': phi, 'Qt': qt, 'delta_Q': 1000}

# -55 dBm
print("-------------------------- -55dBm --------------------------------")
file_path = f"Cavity_resonances_40mK/Res3/risonanza/res3-55dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(
    file_path, None, None, 5.8114e9, 5.8123e9, initial_params=initial_params)
print(f"Qc = {qc:.2e}, Qt = {qt:.2e}, fr = {fr:.6e} Hz")
Qi = 1/qt - 1/qc
fr_list.append(fr)

initial_params = {'fr': fr, 'a': a, 'b': b, 'c': c, 'd': d,
                  'k': k, 'phi': phi, 'Qt': qt, 'delta_Q': 1000}

# -50 dBm
print("-------------------------- -50dBm --------------------------------")
file_path = f"Cavity_resonances_40mK/Res3/risonanza/res3-50dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(
    file_path, None, None, 5.8118e9, 5.8126e9, initial_params=initial_params)
print(f"Qc = {qc:.2e}, Qt = {qt:.2e}, fr = {fr:.6e} Hz")
Qi = 1/qt - 1/qc
fr_list.append(fr)

initial_params = {'fr': fr, 'a': a, 'b': b, 'c': c, 'd': d,
                  'k': k, 'phi': phi, 'Qt': qt, 'delta_Q': 1000}

# -45 dBm
print("-------------------------- -45dBm --------------------------------")
file_path = f"Cavity_resonances_40mK/Res3/risonanza/res3-45dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(
    file_path, None, None, 5.8117e9, 5.8123e9, initial_params=initial_params)
print(f"Qc = {qc:.2e}, Qt = {qt:.2e}, fr = {fr:.6e} Hz")
Qi = 1/qt - 1/qc
fr_list.append(fr)

initial_params = {'fr': fr, 'a': a, 'b': b, 'c': c, 'd': d,
                  'k': k, 'phi': phi, 'Qt': qt, 'delta_Q': 1000}

# -40 dBm
print("-------------------------- -40dBm --------------------------------")
file_path = f"Cavity_resonances_40mK/Res3/risonanza/res3-40dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(
    file_path, None, None, 5.8116e9, 5.8122e9, initial_params=initial_params)
print(f"Qc = {qc:.2e}, Qt = {qt:.2e}, fr = {fr:.6e} Hz")
Qi = 1/qt - 1/qc
fr_list.append(fr)

initial_params = {'fr': fr, 'a': a, 'b': b, 'c': c, 'd': d,
                  'k': k, 'phi': phi, 'Qt': qt, 'delta_Q': 1000}

# -35 dBm
print("-------------------------- -35dBm --------------------------------")
file_path = f"Cavity_resonances_40mK/Res3/risonanza/res3-35dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(
    file_path, None, None, 5.8116e9, 5.8122e9, initial_params=initial_params)
print(f"Qc = {qc:.2e}, Qt = {qt:.2e}, fr = {fr:.6e} Hz")
Qi = 1/qt - 1/qc
fr_list.append(fr)
# Out:
# -------------------------- -60dBm --------------------------------
# ✅ Fit riuscito: False
# 📉 Chi quadro ridotto: 705.5285223516513
# fr = 5811941525.109 Hz, Qt = 7828.36, Qc = 9695.40
# a = -2.604e-02 ± 1.311e-06
# b = -4.944e-07 ± 4.453e-12
# c = 5.006e-14 ± 1.100e-17
# d = 7.621e-19 ± 5.461e-22
# k = 9.310e-01 ± 2.259e-06
# phi = -3.492e-03 ± 2.458e-06
# Qt = 7.828e+03 ± 4.276e-02
# delta_Q = 1.867e+03 ± 3.930e-02
# fr = 5.812e+09 ± 2.248e+01
# Qc = 9.70e+03, Qt = 7.83e+03, fr = 5.811942e+09 Hz
# -------------------------- -55dBm --------------------------------
# ✅ Fit riuscito: False
# 📉 Chi quadro ridotto: 272.33193019414557
# fr = 5811898096.802 Hz, Qt = 8711.88, Qc = 11816.75
# a = -7.208e-02 ± 1.279e-06
# b = -4.088e-07 ± 4.814e-12
# c = 4.952e-14 ± 1.323e-17
# d = 7.941e-19 ± 7.332e-22
# k = 9.652e-01 ± 2.063e-06
# phi = 1.551e-01 ± 2.671e-06
# Qt = 8.712e+03 ± 5.174e-02
# delta_Q = 3.105e+03 ± 4.383e-02
# fr = 5.812e+09 ± 2.112e+01
# ...

# %% [markdown]
# Spostamento frequenza di risonanza

# %%
fr = inverted_list = [fr_list[i] for i in range(len(fr_list)-1, -1, -1)]
dBm = [-35, -40, -45, -50, -55, -60]

plt.figure(figsize=(8, 5))

plt.plot(fr, dBm, color='lightgray', linewidth=2)
plt.scatter(fr, dBm, color='green', s=50, zorder=3)
plt.xlabel('frequency')
plt.ylabel('power (dBm)')
plt.title('power vs frequency')
plt.grid(True)

plt.show()

# %% [markdown]
# # RISONANZA 4 (40mK) al variare della potenza

# %%
fr_list = []

# -60 dBm
print("-------------------------- -60dBm --------------------------------")
initial_params = {
    'a': 0.02, 'b': 10e-9, 'c': 10e-18, 'd': 10e-27,
    'k': 0.936, 'phi': 0.083, 'Qt': 16664,
    'delta_Q': 1000, 'fr': 6.235e9
}
file_path = f"Cavity_resonances_40mK/Res4/risonanza/res4-60dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(
    file_path, None, None, 6.235e9, 6.2365e9,initial_params=initial_params)
print(f"Qc = {qc:.2e}, Qt = {qt:.2e}, fr = {fr:.6e} Hz")
Qi = 1/qt - 1/qc
fr_list.append(fr)

# Aggiorna tutti i parametri
initial_params = {'fr': fr, 'a': a, 'b': b, 'c': c, 'd': d, 'k': k, 'phi': phi, 'Qt': qt, 'delta_Q': 1000}

# -55 dBm
print("-------------------------- -55dBm --------------------------------")
file_path = f"Cavity_resonances_40mK/Res4/risonanza/res4-55dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(
    file_path, initial_params=initial_params)
print(f"Qc = {qc:.2e}, Qt = {qt:.2e}, fr = {fr:.6e} Hz")
Qi = 1/qt - 1/qc
fr_list.append(fr)
initial_params = {'fr': fr, 'a': a, 'b': b, 'c': c, 'd': d, 'k': k, 'phi': phi, 'Qt': qt, 'delta_Q': 1000}

# -50 dBm
print("-------------------------- -50dBm --------------------------------")
file_path = f"Cavity_resonances_40mK/Res4/risonanza/res4-50dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(
    file_path, initial_params=initial_params)
print(f"Qc = {qc:.2e}, Qt = {qt:.2e}, fr = {fr:.6e} Hz")
Qi = 1/qt - 1/qc
fr_list.append(fr)
initial_params = {'fr': fr, 'a': a, 'b': b, 'c': c, 'd': d, 'k': k, 'phi': phi, 'Qt': qt, 'delta_Q': 1000}

# -45 dBm
print("-------------------------- -45dBm --------------------------------")
file_path = f"Cavity_resonances_40mK/Res4/risonanza/res4-45dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(
    file_path, initial_params=initial_params)
print(f"Qc = {qc:.2e}, Qt = {qt:.2e}, fr = {fr:.6e} Hz")
Qi = 1/qt - 1/qc
fr_list.append(fr)
initial_params = {'fr': fr, 'a': a, 'b': b, 'c': c, 'd': d, 'k': k, 'phi': phi, 'Qt': qt, 'delta_Q': 1000}

# -40 dBm
print("-------------------------- -40dBm --------------------------------")
file_path = f"Cavity_resonances_40mK/Res4/risonanza/res4-40dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(
    file_path, initial_params=initial_params)
print(f"Qc = {qc:.2e}, Qt = {qt:.2e}, fr = {fr:.6e} Hz")
Qi = 1/qt - 1/qc
fr_list.append(fr)
initial_params = {'fr': fr, 'a': a, 'b': b, 'c': c, 'd': d, 'k': k, 'phi': phi, 'Qt': qt, 'delta_Q': 1000}

# -35 dBm
print("-------------------------- -35dBm --------------------------------")
file_path = f"Cavity_resonances_40mK/Res4/risonanza/res4-35dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(
    file_path,  initial_params=initial_params)
print(f"Qc = {qc:.2e}, Qt = {qt:.2e}, fr = {fr:.6e} Hz")
Qi = 1/qt - 1/qc
fr_list.append(fr)
# Out:
# -------------------------- -60dBm --------------------------------
# ✅ Fit riuscito: True
# 📉 Chi quadro ridotto: 593.9701344780381
# fr = 6235785000.000 Hz, Qt = 11952.40, Qc = 19191.03
# a = -2.078e-01 ± 1.084e-05
# b = -1.681e-07 ± 3.014e-11
# c = -7.146e-15 ± 4.300e-17
# d = 2.120e-19 ± 1.441e-21
# k = 1.132e+00 ± 1.359e-05
# phi = 1.576e-01 ± 3.082e-05
# Qt = 1.195e+04 ± 7.283e-01
# delta_Q = 7.239e+03 ± 7.623e-01
# fr = 6.236e+09 ± 1.202e+02
# Qc = 1.92e+04, Qt = 1.20e+04, fr = 6.235785e+09 Hz
# -------------------------- -55dBm --------------------------------
# ✅ Fit riuscito: False
# 📉 Chi quadro ridotto: 210.7312179482785
# fr = 6235765000.087 Hz, Qt = 12975.30, Qc = 31959.40
# a = -8.667e-01 ± 9.801e-07
# b = -7.664e-10 ± 6.746e-13
# c = -6.526e-17 ± 3.434e-19
# d = 1.294e-21 ± 3.559e-24
# k = 1.794e+00 ± 1.025e-06
# phi = 3.532e-01 ± 4.635e-06
# Qt = 1.298e+04 ± 1.274e-01
# delta_Q = 1.898e+04 ± 1.797e-01
# fr = 6.236e+09 ± 7.726e-01
# ...

# %% [markdown]
# Spostamento frequenza di risonanza

# %%
fr = inverted_list = [fr_list[i] for i in range(len(fr_list)-1, -1, -1)]
dBm = [-35, -40, -45, -50, -55, -60]

plt.figure(figsize=(8, 5))

plt.plot(fr, dBm, color='lightgray', linewidth=2)
plt.scatter(fr, dBm, color='green', s=50, zorder=3)
plt.xlabel('frequency')
plt.ylabel('power (dBm)')
plt.title('power vs frequency')
plt.grid(True)

plt.show()
