# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
import iminuit as minuit
from iminuit import Minuit
from iminuit.cost import LeastSquares
sys.path.append("..")
import resonance_fit

# %% [markdown]
# # RISONANZA 1 (1K, -50dBm)

# %%
file_path = f"Cavity_resonances_1K/res1-50dBm.txt"


initial_params = {
    'a': 1,  # Ultimo valore di fr ottenuto
    'b': 10e-9,  # Ultimo valore di Qc ottenuto
    'c': 10e-18,       # Impostazione predefinita per c, d, k, phi, Qt, Qc, fr
    'd': 10e-27,
    'k': 2.5,
    'phi': 0.04,
    'Qt': 16703,
    'Qc': 24080,
    'fr': 4395812616  # Ultima frequenza di risonanza come valore iniziale
}


fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path)
# Out:
# Fit riuscito: True
# Chi quadro ridotto: 18.5323528453928
# fr = 4395332070.692 Hz, Qt = 20264.45, Qc = 26383.51
# a = -7.662e-03 ± 9.435e-07
# b = 7.995e-09 ± 1.633e-12
# c = 1.188e-18 ± 2.105e-18
# d = -7.153e-21 ± 5.563e-23
# k = 1.003e+00 ± 1.023e-06
# phi = 5.114e-02 ± 3.449e-06
# Qt = 2.026e+04 ± 1.620e-01
# delta_Q = 6.119e+03 ± 1.800e-01
# fr = 4.395e+09 ± 1.259e+01
# c:\Users\franc\OneDrive\Desktop\QTLab2425\2Dqubit\fit\Resonance fitting\Fit_1K\..\resonance_fit.py:193: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %% [markdown]
# # RISONANZA 2 (1K, -50dBm)

# %%
file_path = f"Cavity_resonances_1K/res2-50dBm.txt"


initial_params = {
    'a': 1,  # Ultimo valore di fr ottenuto
    'b': 10e-9,  # Ultimo valore di Qc ottenuto
    'c': 10e-18,       # Impostazione predefinita per c, d, k, phi, Qt, Qc, fr
    'd': 10e-27,
    'k': 2.5,
    'phi': 0.42,
    'Qt': 10000,
    'Qc': 75000,
    'fr': 5.25658e9  # Ultima frequenza di risonanza come valore iniziale
}



fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path)
# Out:
# Fit riuscito: True
# Chi quadro ridotto: 26.077294036153035
# fr = 5256576866.230 Hz, Qt = 18143.39, Qc = 22441.11
# a = 7.517e-04 ± 1.083e-06
# b = 2.751e-09 ± 1.875e-12
# c = 1.046e-15 ± 2.417e-18
# d = -5.714e-21 ± 6.389e-23
# k = 9.948e-01 ± 1.210e-06
# phi = -5.381e-02 ± 3.272e-06
# Qt = 1.814e+04 ± 1.373e-01
# delta_Q = 4.298e+03 ± 1.573e-01
# fr = 5.257e+09 ± 1.583e+01

# %% [markdown]
# # RISONANZA 3 (1K, -50dBm)

# %%
file_path = f"Cavity_resonances_1K/res3-50dBm.txt"

initial_params = {
    'a': 1,  # Ultimo valore di fr ottenuto
    'b': 10e-9,  # Ultimo valore di Qc ottenuto
    'c': 10e-18,       # Impostazione predefinita per c, d, k, phi, Qt, Qc, fr
    'd': 10e-27,
    'k': 2.5,
    'phi': 0.,
    'Qt': 8000,
    'Qc': 10000,
    'fr': 5.8115e9  # Ultima frequenza di risonanza come valore iniziale
}



fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path, cut_min=5.811e9, cut_max=5.812e9, initial_params=initial_params)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[7], line 17
#       1 file_path = f"Cavity_resonances_1K/res3-50dBm.txt"
#       3 initial_params = {
#       4     'a': 1,  # Ultimo valore di fr ottenuto
#       5     'b': 10e-9,  # Ultimo valore di Qc ottenuto
#    (...)     12     'fr': 5.8115e9  # Ultima frequenza di risonanza come valore iniziale
#      13 }
# ---> 17 fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path, cut_min=5.811e9, cut_max=5.812e9, initial_params=initial_params)
#
# File c:\Users\franc\OneDrive\Desktop\QTLab2425\2Dqubit\fit\Resonance fitting\Fit_1K\..\resonance_fit.py:140, in fit_cut(file_path, unit, Del, cut_min, cut_max, data_min, data_max, initial_params, show)
#     136     return a + b*x + c*x**2 + d*x**3 + k * np.abs(1 - Qt * np.exp(1j*phi) / Qc / (1 + 2j * Qt * x / fr))
#     138 least_squares = LeastSquares(f_cut, amp_cut, amp_err, model)
# --> 140 minuit = Minuit(least_squares, **initial_params)
#     142 minuit.limits["k"] = (0.5, 5)
#     143 minuit.limits["phi"] = (-np.pi, np.pi)
#
# File c:\Users\franc\OneDrive\Desktop\2dqubit\Lib\site-packages\iminuit\minuit.py:683, in Minuit.__init__(***failed resolving arguments***)
#     674     raise ValueError("provided gradient is not a CostGradient")
#     676 self._fcn = FCN(
#     677     fcn,
#     678     grad,
#     679     array_call,
#     680     getattr(fcn, "errordef", 1.0),
#     681 )
# --> 683 self._init_state = _make_init_state(self._pos2var, start, kwds)
#     684 self._values = mutil.ValueView(self)
#     685 self._errors = mutil.ErrorView(self)
#
# File c:\Users\franc\OneDrive\Desktop\2dqubit\Lib\site-packages\iminuit\minuit.py:2647, in _make_init_state(pos2var, args, kwds)
#    2645     for kw in kwds:
#    2646         if kw not in pos2var:
# -> 2647             raise RuntimeError(
#    2648                 f"{kw} is not one of the parameters [{' '.join(pos2var)}]"
#    2649             )
#    2650     nargs = len(kwds)
#    2652 if len(pos2var) != nargs:
#
# RuntimeError: Qc is not one of the parameters [a b c d k phi Qt delta_Q fr]

# %% [markdown]
# # RISONANZA 4 (1K, -50dBm)

# %%
file_path = f"Cavity_resonances_1K/res4-50dBm.txt"



initial_params = {
    'a': 1,  # Ultimo valore di fr ottenuto
    'b': 10e-9,  # Ultimo valore di Qc ottenuto
    'c': 10e-18,       # Impostazione predefinita per c, d, k, phi, Qt, Qc, fr
    'd': 10e-27,
    'k': 1,
    'phi': 0.1,
    'Qt': 14310,
    'Qc': 9770,
    'fr': 6.2353e9  # Ultima frequenza di risonanza come valore iniziale
}


fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path, cut_min=6.2347e9, cut_max=6.2358e9, initial_params=initial_params)
# Out:
# Successo del fit: False
# Chi quadro ridotto: 27.305886251967582
# a = -0.061 +/- 0.000
# b = -0.000 +/- 0.000
# c = -0.000 +/- 0.000
# d = 0.000 +/- 0.000
# k = 1.026 +/- 0.000
# phi = 0.167 +/- 0.000
# Qt = 12365.734 +/- 0.024
# Qc = 9954.395 +/- 0.026
# fr = 6235201636.844 +/- 14.485
