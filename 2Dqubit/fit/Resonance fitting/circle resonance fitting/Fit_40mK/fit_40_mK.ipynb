# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
import iminuit as minuit
from iminuit import Minuit
from iminuit.cost import LeastSquares
sys.path.append("../../..")
import circle

# %% [markdown]
# # RISONANZA 1 (40mK) al variare della potenza

# %%
print("-------------------------- -60dBm --------------------------------")
initial_params = {
    'a': 0.02,
    'b': 10e-9,
    'c': 10e-18,
    'd': 10e-27,
    'k': 0.936,
    'phi': 0.083,
    'Qt': 16664,
    'Qc': 23589,
    'fr': 4395801533
}
file_path = f"Cavity_resonances_40mK/Res1/risonanza/span_2Mhz/res2-60dBm.txt"
Qc, Qi, Qt, fr = circle.fit_full_resonator(file_path, initial_params, 1, delimiter=' ')
print(f"Qc = {Qc:.2e}, Qi = {Qi:.2e}, Qt = {Qt:.2e}, fr = {fr:.6e} Hz")
Qi= 1/Qt - 1/Qc
fr5=fr


print("-------------------------- -55dBm --------------------------------")
initial_params = {
    'a': 0.02,
    'b': 10e-9,
    'c': 10e-18,
    'd': 10e-27,
    'k': 0.936,
    'phi': 0.083,
    'Qt': Qt,
    'Qc': Qc,
    'fr': fr
}
file_path = f"Cavity_resonances_40mK/res2/risonanza/span_2Mhz/res2-55dBm.txt"
Qc, Qi, Qt, fr = circle.fit_full_resonator(file_path, initial_params, 1, delimiter=' ')
print(f"Qc = {Qc:.2e}, Qi = {Qi:.2e}, Qt = {Qt:.2e}, fr = {fr:.6e} Hz")
Qi= 1/Qt - 1/Qc
fr4=fr


print("-------------------------- -50dBm --------------------------------")
initial_params = {
        'a': 0.02,
    'b': 10e-9,
    'c': 10e-18,
    'd': 10e-27,
    'k': 0.936,
    'phi': 0.083,
    'Qt': Qt,
    'Qc': Qc,
    'fr': fr
}
file_path = f"Cavity_resonances_40mK/Res1/risonanza/span_2Mhz/res1-50dBm.txt"
Qc, Qi, Qt, fr = circle.fit_full_resonator(file_path, initial_params, 1, delimiter=' ')
print(f"Qc = {Qc:.2e}, Qi = {Qi:.2e}, Qt = {Qt:.2e}, fr = {fr:.6e} Hz")
Qi= 1/Qt - 1/Qc
fr3=fr


print("-------------------------- -45dBm --------------------------------")
initial_params = {
    'a': 0.02,
    'b': 10e-9,
    'c': 10e-18,
    'd': 10e-27,
    'k': 0.936,
    'phi': 0.083,
    'Qt': Qt,
    'Qc': Qc,
    'fr': fr
}
file_path = f"Cavity_resonances_40mK/Res1/risonanza/span_2Mhz/res1-45dBm.txt"
Qc, Qi, Qt, fr = circle.fit_full_resonator(file_path, initial_params, 1, delimiter=' ')
print(f"Qc = {Qc:.2e}, Qi = {Qi:.2e}, Qt = {Qt:.2e}, fr = {fr:.6e} Hz")
Qi= 1/Qt - 1/Qc
fr2=fr

print("-------------------------- -40dBm --------------------------------")
initial_params = {
    'a': 0.02,
    'b': 10e-9,
    'c': 10e-18,
    'd': 10e-27,
    'k': 0.936,
    'phi': 0.083,
    'Qt': Qt,
    'Qc': Qc,
    'fr': fr
}
file_path = f"Cavity_resonances_40mK/Res1/risonanza/span_2Mhz/res1-40dBm.txt"
Qc, Qi, Qt, fr = circle.fit_full_resonator(file_path, initial_params, 1, delimiter=' ')
print(f"Qc = {Qc:.2e}, Qi = {Qi:.2e}, Qt = {Qt:.2e}, fr = {fr:.6e} Hz")
Qi= 1/Qt - 1/Qc
fr1=fr


print("-------------------------- -35dBm --------------------------------")
initial_params = {
    'a': 0.02,
    'b': 10e-9,
    'c': 10e-18,
    'd': 10e-27,
    'k': 0.936,
    'phi': 0.083,
    'Qt': Qt,
    'Qc': Qc,
    'fr': fr
}
file_path = f"Cavity_resonances_40mK/Res1/risonanza/span_2Mhz/res1-35dBm.txt"
Qc, Qi, Qt, fr = circle.fit_full_resonator(file_path, initial_params, 1, delimiter=' ')
print(f"Qc = {Qc:.2e}, Qi = {Qi:.2e}, Qt = {Qt:.2e}, fr = {fr:.6e} Hz")
Qi= 1/Qt - 1/Qc
fr0=fr
# Out:
# -------------------------- -60dBm --------------------------------
# Qc = 3.81e+04, Qi = 6.01e+04, Qt = 2.33e+04, fr = 4.395815e+09 Hz
# -------------------------- -55dBm --------------------------------
# Qc = 3.81e+04, Qi = 6.23e+04, Qt = 2.37e+04, fr = 4.395815e+09 Hz
# -------------------------- -50dBm --------------------------------
# Qc = 3.81e+04, Qi = 6.54e+04, Qt = 2.41e+04, fr = 4.395814e+09 Hz
# -------------------------- -45dBm --------------------------------
# Qc = 3.77e+04, Qi = 7.06e+04, Qt = 2.46e+04, fr = 4.395806e+09 Hz
# -------------------------- -40dBm --------------------------------
# Qc = 3.75e+04, Qi = 7.78e+04, Qt = 2.53e+04, fr = 4.395779e+09 Hz
# -------------------------- -35dBm --------------------------------
# Qc = 3.78e+04, Qi = 8.88e+04, Qt = 2.65e+04, fr = 4.395700e+09 Hz

# %% [markdown]
# Spostamento della frequenza di risonanza

# %%
fr = [fr0, fr1, fr2, fr3, fr4, fr5]
dBm = [-35, -40, -45, -50, -55, -60]

plt.figure(figsize=(8, 5))

plt.plot(fr, dBm, color='lightgray', linewidth=2)
plt.scatter(fr, dBm, color='green', s=50, zorder=3)
plt.xlabel('frequency')
plt.ylabel('power (dBm)')
plt.title('power vs frequency')
plt.grid(True)

plt.show()

# %% [markdown]
# fit singolo 60dBm

# %% [markdown]
# # RISONANZA 2 (40mK) al variare della potenza

# %%
print("-------------------------- -60dBm --------------------------------")

initial_params = {
    'a': 0.02,
    'b': 10e-9,
    'c': 10e-18,
    'd': 10e-27,
    'k': 0.936,
    'phi': 0.2,
    'Qt': 10664,
    'Qc': 11589,
    'fr': 5257048082
}
file_path = f"Cavity_resonances_40mK/Res2/risonanza/res2-60dBm.txt"
Qc, Qi, Qt, fr = circle.fit_full_resonator(file_path, initial_params, 1, delimiter=' ')
print(f"Qc = {Qc:.2e}, Qi = {Qi:.2e}, Qt = {Qt:.2e}, fr = {fr:.6e} Hz")
Qi= 1/Qt - 1/Qc
fr5=fr


print("-------------------------- -55dBm --------------------------------")
initial_params = {
    'a': 0.02,
    'b': 10e-9,
    'c': 10e-18,
    'd': 10e-27,
    'k': 0.936,
    'phi': 0.083,
    'Qt': Qt,
    'Qc': Qc,
    'fr': fr
}
file_path = f"Cavity_resonances_40mK/Res2/risonanza/res2-55dBm.txt"
Qc, Qi, Qt, fr = circle.fit_full_resonator(file_path, initial_params, 1, delimiter=' ')
print(f"Qc = {Qc:.2e}, Qi = {Qi:.2e}, Qt = {Qt:.2e}, fr = {fr:.6e} Hz")
Qi= 1/Qt - 1/Qc
fr4=fr


print("-------------------------- -50dBm --------------------------------")
initial_params = {
        'a': 0.02,
    'b': 10e-9,
    'c': 10e-18,
    'd': 10e-27,
    'k': 0.936,
    'phi': 0.083,
    'Qt': Qt,
    'Qc': Qc,
    'fr': fr
}
file_path = f"Cavity_resonances_40mK/Res2/risonanza/res2-50dBm.txt"
Qc, Qi, Qt, fr = circle.fit_full_resonator(file_path, initial_params, 1, delimiter=' ')
print(f"Qc = {Qc:.2e}, Qi = {Qi:.2e}, Qt = {Qt:.2e}, fr = {fr:.6e} Hz")
Qi= 1/Qt - 1/Qc
fr3=fr


print("-------------------------- -45dBm --------------------------------")
initial_params = {
    'a': 0.02,
    'b': 10e-9,
    'c': 10e-18,
    'd': 10e-27,
    'k': 0.936,
    'phi': 0.083,
    'Qt': Qt,
    'Qc': Qc,
    'fr': fr
}
file_path = f"Cavity_resonances_40mK/Res2/risonanza/res2-45dBm.txt"
Qc, Qi, Qt, fr = circle.fit_full_resonator(file_path, initial_params, 1, delimiter=' ')
print(f"Qc = {Qc:.2e}, Qi = {Qi:.2e}, Qt = {Qt:.2e}, fr = {fr:.6e} Hz")
Qi= 1/Qt - 1/Qc
fr2=fr

print("-------------------------- -40dBm --------------------------------")
initial_params = {
    'a': 0.02,
    'b': 10e-9,
    'c': 10e-18,
    'd': 10e-27,
    'k': 0.936,
    'phi': 0.083,
    'Qt': Qt,
    'Qc': Qc,
    'fr': fr
}
file_path = f"Cavity_resonances_40mK/Res2/risonanza/res2-40dBm.txt"
Qc, Qi, Qt, fr = circle.fit_full_resonator(file_path, initial_params, 1, delimiter=' ')
print(f"Qc = {Qc:.2e}, Qi = {Qi:.2e}, Qt = {Qt:.2e}, fr = {fr:.6e} Hz")
Qi= 1/Qt - 1/Qc
fr1=fr


print("-------------------------- -35dBm --------------------------------")
initial_params = {
    'a': 0.02,
    'b': 10e-9,
    'c': 10e-18,
    'd': 10e-27,
    'k': 0.936,
    'phi': 0.083,
    'Qt': Qt,
    'Qc': Qc,
    'fr': fr
}
file_path = f"Cavity_resonances_40mK/Res2/risonanza/res2-35dBm.txt"
Qc, Qi, Qt, fr = circle.fit_full_resonator(file_path, initial_params, 1, delimiter=' ')
print(f"Qc = {Qc:.2e}, Qi = {Qi:.2e}, Qt = {Qt:.2e}, fr = {fr:.6e} Hz")
Qi= 1/Qt - 1/Qc
fr0=fr
# Out:
# -------------------------- -60dBm --------------------------------
# Qc = 1.77e+04, Qi = 3.36e+04, Qt = 1.16e+04, fr = 5.257107e+09 Hz
# -------------------------- -55dBm --------------------------------
# Qc = 2.67e+04, Qi = 5.24e+04, Qt = 1.77e+04, fr = 5.257106e+09 Hz
# -------------------------- -50dBm --------------------------------
# Qc = 3.63e+04, Qi = 7.34e+04, Qt = 2.43e+04, fr = 5.257105e+09 Hz
# -------------------------- -45dBm --------------------------------
# Qc = 3.63e+04, Qi = 7.75e+04, Qt = 2.47e+04, fr = 5.257103e+09 Hz
# -------------------------- -40dBm --------------------------------
# Qc = 3.60e+04, Qi = 8.36e+04, Qt = 2.52e+04, fr = 5.257092e+09 Hz
# -------------------------- -35dBm --------------------------------
# Qc = 3.58e+04, Qi = 9.21e+04, Qt = 2.58e+04, fr = 5.257058e+09 Hz

# %% [markdown]
# Spostamento della frequenza di risonanza

# %%
fr = [fr0, fr1, fr2, fr3, fr4, fr5]
dBm = [-35, -40, -45, -50, -55, -60]

plt.figure(figsize=(8, 5))

plt.plot(fr, dBm, color='lightgray', linewidth=2)
plt.scatter(fr, dBm, color='green', s=50, zorder=3)
plt.xlabel('frequency')
plt.ylabel('power (dBm)')
plt.title('power vs frequency')
plt.grid(True)

plt.show()

# %% [markdown]
# # RISONANZA 3 (40mK) al variare della potenza

# %%
print("-------------------------- -60dBm --------------------------------")

initial_params = {
    'a': 0.02,
    'b': 10e-9,
    'c': 10e-18,
    'd': 10e-27,
    'k': 1,
    'phi': 0.45,
    'Qt': 4000,
    'Qc': 23000,
    'fr': 5811900000
}

file_path = f"Cavity_resonances_40mK/Res3/risonanza/res3-60dBm.txt"
Qc, Qi, Qt, fr = circle.fit_full_resonator(file_path, initial_params, 1, delimiter=' ')
print(f"Qc = {Qc:.2e}, Qi = {Qi:.2e}, Qt = {Qt:.2e}, fr = {fr:.6e} Hz")
Qi= 1/Qt - 1/Qc
fr5=fr


print("-------------------------- -55dBm --------------------------------")
initial_params = {
    'a': 0.02,
    'b': 10e-9,
    'c': 10e-18,
    'd': 10e-27,
    'k': 0.936,
    'phi': 0.083,
    'Qt': Qt,
    'Qc': Qc,
    'fr': fr
}
file_path = f"Cavity_resonances_40mK/Res3/risonanza/res3-55dBm.txt"
Qc, Qi, Qt, fr = circle.fit_full_resonator(file_path, initial_params, 1, delimiter=' ')
print(f"Qc = {Qc:.2e}, Qi = {Qi:.2e}, Qt = {Qt:.2e}, fr = {fr:.6e} Hz")
Qi= 1/Qt - 1/Qc
fr4=fr


print("-------------------------- -50dBm --------------------------------")
initial_params = {
        'a': 0.02,
    'b': 10e-9,
    'c': 10e-18,
    'd': 10e-27,
    'k': 0.936,
    'phi': 0.083,
    'Qt': Qt,
    'Qc': Qc,
    'fr': fr
}
file_path = f"Cavity_resonances_40mK/Res3/risonanza/res3-50dBm.txt"
Qc, Qi, Qt, fr = circle.fit_full_resonator(file_path, initial_params, 1, delimiter=' ')
print(f"Qc = {Qc:.2e}, Qi = {Qi:.2e}, Qt = {Qt:.2e}, fr = {fr:.6e} Hz")
Qi= 1/Qt - 1/Qc
fr3=fr


print("-------------------------- -45dBm --------------------------------")
initial_params = {
    'a': 0.02,
    'b': 10e-9,
    'c': 10e-18,
    'd': 10e-27,
    'k': 0.936,
    'phi': 0.083,
    'Qt': Qt,
    'Qc': Qc,
    'fr': fr
}
file_path = f"Cavity_resonances_40mK/Res3/risonanza/res3-45dBm.txt"
Qc, Qi, Qt, fr = circle.fit_full_resonator(file_path, initial_params, 1, delimiter=' ')
print(f"Qc = {Qc:.2e}, Qi = {Qi:.2e}, Qt = {Qt:.2e}, fr = {fr:.6e} Hz")
Qi= 1/Qt - 1/Qc
fr2=fr

print("-------------------------- -40dBm --------------------------------")
initial_params = {
    'a': 0.02,
    'b': 10e-9,
    'c': 10e-18,
    'd': 10e-27,
    'k': 0.936,
    'phi': 0.083,
    'Qt': Qt,
    'Qc': Qc,
    'fr': fr
}
file_path = f"Cavity_resonances_40mK/Res3/risonanza/res3-40dBm.txt"
Qc, Qi, Qt, fr = circle.fit_full_resonator(file_path, initial_params, 1, delimiter=' ')
print(f"Qc = {Qc:.2e}, Qi = {Qi:.2e}, Qt = {Qt:.2e}, fr = {fr:.6e} Hz")
Qi= 1/Qt - 1/Qc
fr1=fr


print("-------------------------- -35dBm --------------------------------")
initial_params = {
    'a': 0.02,
    'b': 10e-9,
    'c': 10e-18,
    'd': 10e-27,
    'k': 0.936,
    'phi': 0.083,
    'Qt': Qt,
    'Qc': Qc,
    'fr': fr
}
file_path = f"Cavity_resonances_40mK/Res3/risonanza/res3-35dBm.txt"
Qc, Qi, Qt, fr = circle.fit_full_resonator(file_path, initial_params, 1, delimiter=' ')
print(f"Qc = {Qc:.2e}, Qi = {Qi:.2e}, Qt = {Qt:.2e}, fr = {fr:.6e} Hz")
Qi= 1/Qt - 1/Qc
fr0=fr
# Out:
# -------------------------- -60dBm --------------------------------
# Qc = 1.27e+04, Qi = 4.04e+04, Qt = 9.66e+03, fr = 5.811826e+09 Hz
# -------------------------- -55dBm --------------------------------
# Qc = 1.46e+04, Qi = 4.22e+04, Qt = 1.08e+04, fr = 5.811871e+09 Hz
# -------------------------- -50dBm --------------------------------
# Qc = 1.45e+04, Qi = 4.46e+04, Qt = 1.10e+04, fr = 5.811872e+09 Hz
# -------------------------- -45dBm --------------------------------
# Qc = 1.45e+04, Qi = 4.63e+04, Qt = 1.10e+04, fr = 5.811868e+09 Hz
# -------------------------- -40dBm --------------------------------
# Qc = 1.45e+04, Qi = 4.86e+04, Qt = 1.12e+04, fr = 5.811862e+09 Hz
# -------------------------- -35dBm --------------------------------
# Qc = 1.44e+04, Qi = 5.11e+04, Qt = 1.12e+04, fr = 5.811842e+09 Hz

# %% [markdown]
# Spostamento frequenza di risonanza

# %%
fr = [fr0, fr1, fr2, fr3, fr4, fr5]
dBm = [-35, -40, -45, -50, -55, -60]

plt.figure(figsize=(8, 5))

plt.plot(fr, dBm, color='lightgray', linewidth=2)
plt.scatter(fr, dBm, color='green', s=50, zorder=3)
plt.xlabel('frequency')
plt.ylabel('power (dBm)')
plt.title('power vs frequency')
plt.grid(True)

plt.show()

# %% [markdown]
# # RISONANZA 4 (40mK) al variare della potenza

# %%
print("-------------------------- -60dBm --------------------------------")
"""
initial_params = {
    'a': 0.02,
    'b': 10e-9,
    'c': 10e-18,
    'd': 10e-27,
    'k': 1,
    'phi': 0.45,
    'Qt': 4000,
    'Qc': 23000,
    'fr': 5811900000
}
"""
file_path = f"Cavity_resonances_40mK/Res4/risonanza/res4-60dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path, cut_min=6.2355e9, cut_max=6.2365e9, initial_params=initial_params)
fr5=fr


print("-------------------------- -55dBm --------------------------------")
initial_params = {
    'a': a,
    'b': b,
    'c': c,
    'd': d,
    'k': k,
    'phi': phi,
    'Qt': qt,
    'Qc': qc,
    'fr': fr
}
file_path = f"Cavity_resonances_40mK/Res4/risonanza/res4-55dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path, cut_min=6.235e9, cut_max=6.237e9, initial_params=initial_params)
fr4=fr


print("-------------------------- -50dBm --------------------------------")
initial_params = {
    'a': a,
    'b': b,
    'c': c,
    'd': d,
    'k': k,
    'phi': phi,
    'Qt': qt,
    'Qc': qc,
    'fr': fr
}
file_path = f"Cavity_resonances_40mK/Res4/risonanza/res4-50dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path, cut_min=6.235e9, cut_max=6.237e9, initial_params=initial_params)
fr3=fr


print("-------------------------- -45dBm --------------------------------")
initial_params = {
    'a': a,
    'b': b,
    'c': c,
    'd': d,
    'k': k,
    'phi': 1,
    'Qt': qt,
    'Qc': qc,
    'fr': fr
}
file_path = f"Cavity_resonances_40mK/Res4/risonanza/res4-45dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path, cut_min=6.235e9, cut_max=6.237e9, initial_params=initial_params)
fr2=fr

print("-------------------------- -40dBm --------------------------------")
initial_params = {
    'a': a,
    'b': b,
    'c': c,
    'd': d,
    'k': k,
    'phi': 1,
    'Qt': qt,
    'Qc': qc,
    'fr': fr
}
file_path = f"Cavity_resonances_40mK/Res4/risonanza/res4-40dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path, cut_min=6.235e9, cut_max=6.237e9, initial_params=initial_params)
fr1=fr


print("-------------------------- -35dBm --------------------------------")
initial_params = {
    'a': a,
    'b': b,
    'c': c,
    'd': d,
    'k': k,
    'phi': 1,
    'Qt': qt,
    'Qc': qc,
    'fr': fr
}
file_path = f"Cavity_resonances_40mK/Res4/risonanza/res4-35dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path, cut_min=6.235e9, cut_max=6.237e9, initial_params=initial_params)
fr0=fr
# Out:
# -------------------------- -60dBm --------------------------------
# Successo del fit: True
# Chi quadro ridotto: 622.7794992913905
# a = -4.622 +/- 0.000
# b = -0.000 +/- 0.000
# c = 0.000 +/- 0.000
# d = -0.000 +/- 0.000
# k = 5.382 +/- 0.000
# phi = 0.012 +/- 0.000
# Qt = 17435.078 +/- 0.002
# Qc = 9168.654 +/- 0.001
# fr = 6235792586.435 +/- 10.840
# -------------------------- -55dBm --------------------------------
# Successo del fit: True
# Chi quadro ridotto: 219.60018081059542
# a = -4.552 +/- 0.000
# b = -0.000 +/- 0.000
# c = 0.000 +/- 0.000
# d = -0.000 +/- 0.000
# k = 5.453 +/- 0.000
# phi = 0.026 +/- 0.000
# Qt = 14852.499 +/- 0.001
# Qc = 7895.531 +/- 0.000
# fr = 6235771211.583 +/- 5.535
# -------------------------- -50dBm --------------------------------
# Successo del fit: True
# Chi quadro ridotto: 88.04107083562775
# a = -4.538 +/- 0.000
# b = -0.000 +/- 0.000
# c = 0.000 +/- 0.000
# d = 0.000 +/- 0.000
# k = 5.467 +/- 0.000
# phi = 0.026 +/- 0.000
# ...

# %% [markdown]
# Spostamento frequenza di risonanza

# %%
fr = [fr0, fr1, fr2, fr3, fr4, fr5]
dBm = [-35, -40, -45, -50, -55, -60]

plt.figure(figsize=(8, 5))

plt.plot(fr, dBm, color='lightgray', linewidth=2)
plt.scatter(fr, dBm, color='green', s=50, zorder=3)
plt.xlabel('frequency')
plt.ylabel('power (dBm)')
plt.title('power vs frequency')
plt.grid(True)

plt.show()
