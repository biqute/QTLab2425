# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
import iminuit as minuit
from iminuit import Minuit
from iminuit.cost import LeastSquares
sys.path.append("../../fit")
import resonance_fit

# %% [markdown]
# # FIT PRIMA RISONANZA 1.3K -50dBm

# %%
file_path = f"Cavity_resonances_1.3K/res1-50dBm.txt"


initial_params = {
    'a': 1,  # Ultimo valore di fr ottenuto
    'b': 10e-9,  # Ultimo valore di Qc ottenuto
    'c': 10e-18,       # Impostazione predefinita per c, d, k, phi, Qt, Qc, fr
    'd': 10e-27,
    'k': 2.5,
    'phi': 0.04,
    'Qt': 16703,
    'Qc': 24080,
    'fr': 4395812616  # Ultima frequenza di risonanza come valore iniziale
}


fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit(file_path, initial_params=initial_params)
# Out:
# Successo del fit: True
# Chi quadro ridotto: 18.045184207529786
# a = 0.003 +/- 0.000
# b = 0.000 +/- 0.000
# c = 0.000 +/- 0.000
# d = -0.000 +/- 0.000
# k = 0.993 +/- 0.000
# phi = 0.041 +/- 0.000
# Qt = 20421.470 +/- 0.227
# Qc = 26148.668 +/- 0.282
# fr = 4394892726.599 +/- 19.184

# %% [markdown]
# # FIT SECONDA RISONANZA 1.3K -50dBm

# %%
file_path = f"Cavity_resonances_1.3K/res2-50dBm.txt"


initial_params = {
    'a': 1,  # Ultimo valore di fr ottenuto
    'b': 10e-9,  # Ultimo valore di Qc ottenuto
    'c': 10e-18,       # Impostazione predefinita per c, d, k, phi, Qt, Qc, fr
    'd': 10e-27,
    'k': 2.5,
    'phi': 0.42,
    'Qt': 10000,
    'Qc': 75000,
    'fr': 5809178611  # Ultima frequenza di risonanza come valore iniziale
}



fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit(file_path, initial_params=initial_params)
# Out:
# Successo del fit: True
# Chi quadro ridotto: 53.71617948354586
# a = -0.556 +/- 0.000
# b = -0.000 +/- 0.000
# c = 0.000 +/- 0.000
# d = 0.000 +/- 0.000
# k = 1.545 +/- 0.000
# phi = -0.121 +/- 0.000
# Qt = 20886.100 +/- 0.077
# Qc = 40420.715 +/- 0.118
# fr = 5256019236.654 +/- 8.691

# %% [markdown]
# # FIT TERZA RISONANZA 1.3K -50dBm

# %%
file_path = f"Cavity_resonances_1.3K/res3-50dBm.txt"

initial_params = {
    'a': 1,  # Ultimo valore di fr ottenuto
    'b': 10e-9,  # Ultimo valore di Qc ottenuto
    'c': 10e-18,       # Impostazione predefinita per c, d, k, phi, Qt, Qc, fr
    'd': 10e-27,
    'k': 2.5,
    'phi': 0.42,
    'Qt': 10000,
    'Qc': 75000,
    'fr': 5809178611  # Ultima frequenza di risonanza come valore iniziale
}



fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit(file_path, initial_params=initial_params)
# Out:
# Successo del fit: False
# Chi quadro ridotto: 103.75444015837046
# a = -3.029 +/- 0.000
# b = -0.000 +/- 0.000
# c = -0.000 +/- 0.000
# d = 0.000 +/- 0.000
# k = 3.948 +/- 0.000
# phi = 0.252 +/- 0.000
# Qt = 10801.137 +/- 0.141
# Qc = 56107.396 +/- 0.533
# fr = 5810770000.013 +/- 3.391

# %% [markdown]
# # FIT QUARTA RISONANZA 1.3K -50dBm

# %%
file_path = f"Cavity_resonances_1.3K/res4-50dBm.txt"



initial_params = {
    'a': 1,  # Ultimo valore di fr ottenuto
    'b': 10e-9,  # Ultimo valore di Qc ottenuto
    'c': 10e-18,       # Impostazione predefinita per c, d, k, phi, Qt, Qc, fr
    'd': 10e-27,
    'k': 1,
    'phi': 0.01,
    'Qt': 14310,
    'Qc': 22770,
    'fr': 6202500000  # Ultima frequenza di risonanza come valore iniziale
}


fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit(file_path, initial_params=initial_params)
# Out:
# Successo del fit: True
# Chi quadro ridotto: 61.755121979888635
# a = -0.149 +/- 0.000
# b = -0.000 +/- 0.000
# c = 0.000 +/- 0.000
# d = 0.000 +/- 0.000
# k = 1.093 +/- 0.000
# phi = 0.296 +/- 0.000
# Qt = 12981.933 +/- 0.602
# Qc = 17722.697 +/- 0.760
# fr = 6234648000.000 +/- 64.347
