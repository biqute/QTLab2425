# %%
import numpy as np
import matplotlib.pyplot as plt
import sys 
sys.path.append("../fit")
import resonance_fit

# %%
file_path = "cavity_resonances_40mK/Res2/risonanza/res2-50dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit(file_path)
# Out:
# Successo del fit: True
# Chi quadro ridotto: 61.440833864898124
# a = 0.013 +/- 0.000
# b = -0.000 +/- 0.000
# c = 0.000 +/- 0.000
# d = 0.000 +/- 0.000
# k = 0.977 +/- 0.000
# phi = -0.032 +/- 0.000
# Qt = 15855.329 +/- 0.032
# Qc = 12247.966 +/- 0.033
# fr = 5257107641.809 +/- 15.543
