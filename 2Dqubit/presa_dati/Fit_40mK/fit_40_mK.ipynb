# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
import iminuit as minuit
from iminuit import Minuit
from iminuit.cost import LeastSquares
sys.path.append("../../fit")
import resonance_fit

# %% [markdown]
# # RISONANZA 1 (40mK) al variare della potenza

# %%
print("-------------------------- -60dBm --------------------------------")
initial_params = {
    'a': 0.02,
    'b': 10e-9,
    'c': 10e-18,
    'd': 10e-27,
    'k': 0.936,
    'phi': 0.083,
    'Qt': 16664,
    'Qc': 23589,
    'fr': 4395801533
}
file_path = f"Cavity_resonances_40mK/Res1/risonanza/span_2Mhz/res1-60dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path, cut_min=4.39525e9, cut_max=4.39625e9, initial_params=initial_params)



print("-------------------------- -55dBm --------------------------------")
initial_params = {
    'a': a,
    'b': b,
    'c': c,
    'd': d,
    'k': k,
    'phi': phi,
    'Qt': qt,
    'Qc': qc,
    'fr': fr
}
file_path = f"Cavity_resonances_40mK/Res1/risonanza/span_2Mhz/res1-55dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path, cut_min=4.39525e9, cut_max=4.39625e9, initial_params=initial_params)



print("-------------------------- -50dBm --------------------------------")
initial_params = {
    'a': a,
    'b': b,
    'c': c,
    'd': d,
    'k': k,
    'phi': phi,
    'Qt': qt,
    'Qc': qc,
    'fr': fr
}
file_path = f"Cavity_resonances_40mK/Res1/risonanza/span_2Mhz/res1-50dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path, cut_min=4.39525e9, cut_max=4.39625e9, initial_params=initial_params)



print("-------------------------- -45dBm --------------------------------")
initial_params = {
    'a': a,
    'b': b,
    'c': c,
    'd': d,
    'k': k,
    'phi': phi,
    'Qt': qt,
    'Qc': qc,
    'fr': fr
}
file_path = f"Cavity_resonances_40mK/Res1/risonanza/span_2Mhz/res1-45dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path, cut_min=4.39525e9, cut_max=4.39625e9, initial_params=initial_params)


print("-------------------------- -40dBm --------------------------------")
initial_params = {
    'a': a,
    'b': b,
    'c': c,
    'd': d,
    'k': k,
    'phi': phi,
    'Qt': qt,
    'Qc': qc,
    'fr': fr
}
file_path = f"Cavity_resonances_40mK/Res1/risonanza/span_2Mhz/res1-40dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path, cut_min=4.39525e9, cut_max=4.39625e9, initial_params=initial_params)



print("-------------------------- -35dBm --------------------------------")
initial_params = {
    'a': a,
    'b': b,
    'c': c,
    'd': d,
    'k': k,
    'phi': 1.6,
    'Qt': 10000,
    'Qc': qc,
    'fr': 4.3955e9
}
file_path = f"Cavity_resonances_40mK/Res1/risonanza/span_2Mhz/res1-35dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path, cut_min=4.3956e9, cut_max=4.3959e9, initial_params=initial_params)
# Out:
# -------------------------- -60dBm --------------------------------
# Successo del fit: True
# Chi quadro ridotto: 439.95731810419346
# a = -0.193 +/- 0.000
# b = 0.000 +/- 0.000
# c = -0.000 +/- 0.000
# d = -0.000 +/- 0.000
# k = 1.141 +/- 0.000
# phi = 0.069 +/- 0.000
# Qt = 17413.708 +/- 0.072
# Qc = 32903.627 +/- 0.108
# fr = 4395814588.938 +/- 9.687
# -------------------------- -55dBm --------------------------------
# Successo del fit: True
# Chi quadro ridotto: 157.58325271714583
# a = 0.074 +/- 0.000
# b = 0.000 +/- 0.000
# c = -0.000 +/- 0.000
# d = -0.000 +/- 0.000
# k = 0.900 +/- 0.000
# phi = 0.059 +/- 0.000
# Qt = 15883.874 +/- 0.065
# Qc = 22554.302 +/- 0.082
# fr = 4395813061.261 +/- 9.614
# -------------------------- -50dBm --------------------------------
# Successo del fit: True
# Chi quadro ridotto: 43.548889363244456
# a = 0.018 +/- 0.000
# b = 0.000 +/- 0.000
# c = 0.000 +/- 0.000
# d = -0.000 +/- 0.000
# k = 0.956 +/- 0.000
# phi = 0.060 +/- 0.000
# ...

# %% [markdown]
# # RISONANZA 2 (40mK) al variare della potenza

# %%
print("-------------------------- -60dBm --------------------------------")
"""
initial_params = {
    'a': 0.02,
    'b': 10e-9,
    'c': 10e-18,
    'd': 10e-27,
    'k': 0.936,
    'phi': 0.083,
    'Qt': 16664,
    'Qc': 23589,
    'fr': 4395801533
}
"""
file_path = f"Cavity_resonances_40mK/Res2/risonanza/res2-60dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path, cut_min=5.25640e9, cut_max=5.2578e9)



print("-------------------------- -55dBm --------------------------------")
initial_params = {
    'a': a,
    'b': b,
    'c': c,
    'd': d,
    'k': k,
    'phi': phi,
    'Qt': qt,
    'Qc': qc,
    'fr': 5257200000
}
file_path = f"Cavity_resonances_40mK/Res2/risonanza/res2-55dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path, cut_min=5.25650e9, cut_max=5.25775e9, initial_params=initial_params)



print("-------------------------- -50dBm --------------------------------")
initial_params = {
    'a': a,
    'b': b,
    'c': c,
    'd': d,
    'k': k,
    'phi': phi,
    'Qt': qt,
    'Qc': qc,
    'fr': fr
}
file_path = f"Cavity_resonances_40mK/Res2/risonanza/res2-50dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path, cut_min=5.25650e9, cut_max=5.25775e9, initial_params=initial_params)



print("-------------------------- -45dBm --------------------------------")
initial_params = {
    'a': a,
    'b': b,
    'c': c,
    'd': d,
    'k': k,
    'phi': phi,
    'Qt': qt,
    'Qc': qc,
    'fr': fr
}
file_path = f"Cavity_resonances_40mK/Res2/risonanza/res2-45dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path, cut_min=5.25650e9, cut_max=5.25775e9, initial_params=initial_params)


print("-------------------------- -40dBm --------------------------------")
initial_params = {
    'a': a,
    'b': b,
    'c': c,
    'd': d,
    'k': k,
    'phi': phi,
    'Qt': qt,
    'Qc': qc,
    'fr': fr
}
file_path = f"Cavity_resonances_40mK/Res2/risonanza/res2-40dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path, cut_min=5.25650e9, cut_max=5.25775e9, initial_params=initial_params)



print("-------------------------- -35dBm --------------------------------")
initial_params = {
    'a': a,
    'b': b,
    'c': c,
    'd': d,
    'k': k,
    'phi': 1,
    'Qt': 19000,
    'Qc': qc,
    'fr': 5257000000
}
file_path = f"Cavity_resonances_40mK/Res2/risonanza/res2-35dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path, cut_min=5.2567e9, cut_max=5.2574e9, initial_params=initial_params)
# Out:
# -------------------------- -60dBm --------------------------------
# Successo del fit: False
# Chi quadro ridotto: 578.8863878925388
# a = -0.148 +/- 0.000
# b = 0.000 +/- 0.000
# c = 0.000 +/- 0.000
# d = -0.000 +/- 0.000
# k = 1.074 +/- 0.000
# phi = -0.074 +/- 0.000
# Qt = 16692.518 +/- 0.107
# Qc = 28509.805 +/- 0.149
# fr = 5257110557.342 +/- 18.089
# -------------------------- -55dBm --------------------------------
# Successo del fit: True
# Chi quadro ridotto: 194.78002363172632
# a = -0.043 +/- 0.000
# b = 0.000 +/- 0.000
# c = -0.000 +/- 0.000
# d = -0.000 +/- 0.000
# k = 1.018 +/- 0.000
# phi = -0.039 +/- 0.000
# Qt = 16062.332 +/- 0.080
# Qc = 24297.287 +/- 0.103
# fr = 5257105343.304 +/- 14.035
# -------------------------- -50dBm --------------------------------
# Successo del fit: True
# Chi quadro ridotto: 62.54699464409482
# a = -0.053 +/- 0.000
# b = -0.000 +/- 0.000
# c = 0.000 +/- 0.000
# d = -0.000 +/- 0.000
# k = 1.034 +/- 0.000
# phi = -0.058 +/- 0.000
# ...

# %% [markdown]
# # RISONANZA 3 (40mK) al variare della potenza

# %%
print("-------------------------- -60dBm --------------------------------")

initial_params = {
    'a': 0.02,
    'b': 10e-9,
    'c': 10e-18,
    'd': 10e-27,
    'k': 1,
    'phi': 0.45,
    'Qt': 4000,
    'Qc': 23000,
    'fr': 5811900000
}

file_path = f"Cavity_resonances_40mK/Res3/risonanza/res3-60dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path, cut_min=5.8115e9, cut_max=5.8125e9, initial_params=initial_params)



print("-------------------------- -55dBm --------------------------------")
initial_params = {
    'a': a,
    'b': b,
    'c': c,
    'd': d,
    'k': k,
    'phi': phi,
    'Qt': qt,
    'Qc': qc,
    'fr': fr
}
file_path = f"Cavity_resonances_40mK/Res3/risonanza/res3-55dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path, cut_min=5.8115e9, cut_max=5.8125e9, initial_params=initial_params)



print("-------------------------- -50dBm --------------------------------")
initial_params = {
    'a': a,
    'b': b,
    'c': c,
    'd': d,
    'k': k,
    'phi': phi,
    'Qt': qt,
    'Qc': qc,
    'fr': fr
}
file_path = f"Cavity_resonances_40mK/Res3/risonanza/res3-50dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path, cut_min=5.8115e9, cut_max=5.8125e9, initial_params=initial_params)



print("-------------------------- -45dBm --------------------------------")
initial_params = {
    'a': a,
    'b': b,
    'c': c,
    'd': d,
    'k': k,
    'phi': 1,
    'Qt': qt,
    'Qc': qc,
    'fr': fr
}
file_path = f"Cavity_resonances_40mK/Res3/risonanza/res3-45dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path, cut_min=5.8115e9, cut_max=5.8125e9, initial_params=initial_params)


print("-------------------------- -40dBm --------------------------------")
initial_params = {
    'a': a,
    'b': b,
    'c': c,
    'd': d,
    'k': k,
    'phi': 1,
    'Qt': qt,
    'Qc': qc,
    'fr': fr
}
file_path = f"Cavity_resonances_40mK/Res3/risonanza/res3-40dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path, cut_min=5.8115e9, cut_max=5.8125e9, initial_params=initial_params)



print("-------------------------- -35dBm --------------------------------")
initial_params = {
    'a': a,
    'b': b,
    'c': c,
    'd': d,
    'k': k,
    'phi': 1,
    'Qt': 15000,
    'Qc': qc,
    'fr': 5.8118e9
}
file_path = f"Cavity_resonances_40mK/Res3/risonanza/res3-35dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path, cut_min=5.8115e9, cut_max=5.8125e9, initial_params=initial_params)
# Out:
# -------------------------- -60dBm --------------------------------
# Successo del fit: True
# Chi quadro ridotto: 705.9514181169675
# a = -0.011 +/- 0.000
# b = -0.000 +/- 0.000
# c = -0.000 +/- 0.000
# d = 0.000 +/- 0.000
# k = 0.939 +/- 0.000
# phi = 0.049 +/- 0.000
# Qt = 7635.853 +/- 0.029
# Qc = 9332.924 +/- 0.032
# fr = 5811926000.001 +/- 4.584
# -------------------------- -55dBm --------------------------------
# Successo del fit: False
# Chi quadro ridotto: 261.20399473015686
# a = 0.005 +/- 0.000
# b = -0.000 +/- 0.000
# c = -0.000 +/- 0.000
# d = 0.000 +/- 0.000
# k = 1.164 +/- 0.000
# phi = 0.131 +/- 0.000
# Qt = 6287.835 +/- 0.013
# Qc = 7425.521 +/- 0.013
# fr = 5811887376.367 +/- 13.688
# -------------------------- -50dBm --------------------------------
# Successo del fit: True
# Chi quadro ridotto: 83.23813054578316
# a = -0.076 +/- 0.000
# b = -0.000 +/- 0.000
# c = -0.000 +/- 0.000
# d = 0.000 +/- 0.000
# k = 1.046 +/- 0.000
# phi = 0.085 +/- 0.000
# ...

# %% [markdown]
# # RISONANZA 4 (40mK) al variare della potenza

# %%
print("-------------------------- -60dBm --------------------------------")

initial_params = {
    'a': 0.02,
    'b': 10e-9,
    'c': 10e-18,
    'd': 10e-27,
    'k': 1,
    'phi': 0.45,
    'Qt': 4000,
    'Qc': 23000,
    'fr': 5811900000
}

file_path = f"Cavity_resonances_40mK/Res4/risonanza/res4-60dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut2(file_path, cut_min=6.235e9, cut_max=6.237e9, initial_params=initial_params)



print("-------------------------- -55dBm --------------------------------")
initial_params = {
    'a': a,
    'b': b,
    'c': c,
    'd': d,
    'k': k,
    'phi': phi,
    'Qt': qt,
    'Qc': qc,
    'fr': fr
}
file_path = f"Cavity_resonances_40mK/Res4/risonanza/res4-55dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut2(file_path, cut_min=6.235e9, cut_max=6.237e9, initial_params=initial_params)



print("-------------------------- -50dBm --------------------------------")
initial_params = {
    'a': a,
    'b': b,
    'c': c,
    'd': d,
    'k': k,
    'phi': phi,
    'Qt': qt,
    'Qc': qc,
    'fr': fr
}
file_path = f"Cavity_resonances_40mK/Res4/risonanza/res4-50dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut2(file_path, cut_min=6.235e9, cut_max=6.237e9, initial_params=initial_params)



print("-------------------------- -45dBm --------------------------------")
initial_params = {
    'a': a,
    'b': b,
    'c': c,
    'd': d,
    'k': k,
    'phi': 1,
    'Qt': qt,
    'Qc': qc,
    'fr': fr
}
file_path = f"Cavity_resonances_40mK/Res4/risonanza/res4-45dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut2(file_path, cut_min=6.23550e9, cut_max=6.23628e9, initial_params=initial_params)


print("-------------------------- -40dBm --------------------------------")
initial_params = {
    'a': a,
    'b': b,
    'c': c,
    'd': d,
    'k': k,
    'phi': 1,
    'Qt': qt,
    'Qc': qc,
    'fr': fr
}
file_path = f"Cavity_resonances_40mK/Res4/risonanza/res4-40dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut2(file_path, cut_min=6.23550e9, cut_max=6.23628e9, initial_params=initial_params)



print("-------------------------- -35dBm --------------------------------")
initial_params = {
    'a': a,
    'b': b,
    'c': c,
    'd': d,
    'k': k,
    'phi': 1,
    'Qt': qt,
    'Qc': qc,
    'fr': fr
}
file_path = f"Cavity_resonances_40mK/Res4/risonanza/res4-35dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut2(file_path, cut_min=6.23550e9, cut_max=6.23628e9, initial_params=initial_params)
# Out:
# -------------------------- -60dBm --------------------------------
# Successo del fit: False
# Chi quadro ridotto: 606.4203251673538
# a = -1.801e+00 ± 6.380e-07
# b = -7.155e-08 ± 1.033e-12
# c = -1.729e-14 ± 1.171e-18
# d = 5.830e-20 ± 2.624e-23
# k = 2.730e+00 ± 6.883e-07
# phi = 2.553e-01 ± 2.271e-06
# Qt = 1.348e+04 ± 4.205e-02
# Qc = 5.169e+04 ± 1.187e-01
# fr = 6.236e+09 ± 2.134e+00
# -------------------------- -55dBm --------------------------------
# Successo del fit: False
# Chi quadro ridotto: 1.0190631234119351e+18
# a = -2.383e+13 ± 5.529e-04
# b = 7.000e+03 ± 8.413e-10
# c = -1.137e-04 ± 2.098e-16
# d = -2.691e-10 ± 3.162e-22
# k = 2.384e+13 ± 0.000e+00
# phi = 1.486e+00 ± 1.599e-14
# Qt = 6.296e+02 ± 2.774e-11
# Qc = 4.311e+05 ± 4.278e-08
# fr = 6.236e+09 ± 0.000e+00
# -------------------------- -50dBm --------------------------------
# Successo del fit: False
# Chi quadro ridotto: 127116.049358045
# a = -1.132e+15 ± 4.321e-04
# b = 3.417e-01 ± 3.716e-10
# ...
