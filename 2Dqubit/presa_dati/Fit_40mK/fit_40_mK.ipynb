# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
import iminuit as minuit
from iminuit import Minuit
from iminuit.cost import LeastSquares
sys.path.append("../../fit")
import resonance_fit

# %% [markdown]
# # RISONANZA 1 (40mK) al variare della potenza

# %%
print("-------------------------- -60dBm --------------------------------")
initial_params = {
    'a': 0.02,
    'b': 10e-9,
    'c': 10e-18,
    'd': 10e-27,
    'k': 0.936,
    'phi': 0.083,
    'Qt': 16664,
    'Qc': 23589,
    'fr': 4395801533
}
file_path = f"Cavity_resonances_40mK/Res1/risonanza/span_2Mhz/res1-60dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path, cut_min=4.39525e9, cut_max=4.39625e9, initial_params=initial_params)



print("-------------------------- -55dBm --------------------------------")
initial_params = {
    'a': a,
    'b': b,
    'c': c,
    'd': d,
    'k': k,
    'phi': phi,
    'Qt': qt,
    'Qc': qc,
    'fr': fr
}
file_path = f"Cavity_resonances_40mK/Res1/risonanza/span_2Mhz/res1-55dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path, cut_min=4.39525e9, cut_max=4.39625e9, initial_params=initial_params)



print("-------------------------- -50dBm --------------------------------")
initial_params = {
    'a': a,
    'b': b,
    'c': c,
    'd': d,
    'k': k,
    'phi': phi,
    'Qt': qt,
    'Qc': qc,
    'fr': fr
}
file_path = f"Cavity_resonances_40mK/Res1/risonanza/span_2Mhz/res1-50dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path, cut_min=4.39525e9, cut_max=4.39625e9, initial_params=initial_params)



print("-------------------------- -45dBm --------------------------------")
initial_params = {
    'a': a,
    'b': b,
    'c': c,
    'd': d,
    'k': k,
    'phi': phi,
    'Qt': qt,
    'Qc': qc,
    'fr': fr
}
file_path = f"Cavity_resonances_40mK/Res1/risonanza/span_2Mhz/res1-45dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path, cut_min=4.39525e9, cut_max=4.39625e9, initial_params=initial_params)


print("-------------------------- -40dBm --------------------------------")
initial_params = {
    'a': a,
    'b': b,
    'c': c,
    'd': d,
    'k': k,
    'phi': phi,
    'Qt': qt,
    'Qc': qc,
    'fr': fr
}
file_path = f"Cavity_resonances_40mK/Res1/risonanza/span_2Mhz/res1-40dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path, cut_min=4.39525e9, cut_max=4.39625e9, initial_params=initial_params)



print("-------------------------- -35dBm --------------------------------")
initial_params = {
    'a': a,
    'b': b,
    'c': c,
    'd': d,
    'k': k,
    'phi': 1.6,
    'Qt': 10000,
    'Qc': qc,
    'fr': 4.3955e9
}
file_path = f"Cavity_resonances_40mK/Res1/risonanza/span_2Mhz/res1-35dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path, cut_min=4.3956e9, cut_max=4.3959e9, initial_params=initial_params)
# Out:
# -------------------------- -60dBm --------------------------------
# Successo del fit: True
# Chi quadro ridotto: 439.95731810419346
# a = -0.193 +/- 0.000
# b = 0.000 +/- 0.000
# c = -0.000 +/- 0.000
# d = -0.000 +/- 0.000
# k = 1.141 +/- 0.000
# phi = 0.069 +/- 0.000
# Qt = 17413.708 +/- 0.072
# Qc = 32903.627 +/- 0.108
# fr = 4395814588.938 +/- 9.687
# -------------------------- -55dBm --------------------------------
# Successo del fit: True
# Chi quadro ridotto: 157.58325271714583
# a = 0.074 +/- 0.000
# b = 0.000 +/- 0.000
# c = -0.000 +/- 0.000
# d = -0.000 +/- 0.000
# k = 0.900 +/- 0.000
# phi = 0.059 +/- 0.000
# Qt = 15883.874 +/- 0.065
# Qc = 22554.302 +/- 0.082
# fr = 4395813061.261 +/- 9.614
# -------------------------- -50dBm --------------------------------
# Successo del fit: True
# Chi quadro ridotto: 43.548889363244456
# a = 0.018 +/- 0.000
# b = 0.000 +/- 0.000
# c = 0.000 +/- 0.000
# d = -0.000 +/- 0.000
# k = 0.956 +/- 0.000
# phi = 0.060 +/- 0.000
# Qt = 17048.909 +/- 0.073
# Qc = 25529.508 +/- 0.095
# fr = 4395811196.827 +/- 9.542
# -------------------------- -45dBm --------------------------------
# Successo del fit: True
# Chi quadro ridotto: 16.208555942990717
# a = 0.022 +/- 0.000
# b = 0.000 +/- 0.000
# c = 0.000 +/- 0.000
# d = -0.000 +/- 0.000
# k = 0.965 +/- 0.000
# phi = 0.114 +/- 0.000
# Qt = 17487.090 +/- 0.084
# Qc = 25283.103 +/- 0.106
# fr = 4395798534.624 +/- 10.247
# -------------------------- -40dBm --------------------------------
# Successo del fit: True
# Chi quadro ridotto: 26.875033874787288
# a = -0.176 +/- 0.000
# b = 0.000 +/- 0.000
# c = 0.000 +/- 0.000
# d = -0.000 +/- 0.000
# k = 1.140 +/- 0.000
# phi = 0.284 +/- 0.000
# Qt = 20150.825 +/- 0.230
# Qc = 33715.410 +/- 0.314
# fr = 4395759497.683 +/- 22.525
# -------------------------- -35dBm --------------------------------
# Successo del fit: False
# Chi quadro ridotto: 28.079206192752796
# a = -0.599 +/- 0.000
# b = -0.000 +/- 0.000
# c = 0.000 +/- 0.000
# d = -0.000 +/- 0.000
# k = 1.127 +/- 0.000
# phi = 1.475 +/- 0.000
# Qt = 70078.308 +/- 2.068
# Qc = 170062.875 +/- 4.430
# fr = 4395646217.783 +/- 17.299

# %% [markdown]
# # RISONANZA 2 (40mK) al variare della potenza

# %%
print("-------------------------- -60dBm --------------------------------")
initial_params = {
    'a': 0.02,
    'b': 10e-9,
    'c': 10e-18,
    'd': 10e-27,
    'k': 0.936,
    'phi': 0.083,
    'Qt': 16664,
    'Qc': 23589,
    'fr': 4395801533
}
file_path = f"Cavity_resonances_40mK/Res2/risonanza/res2-60dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path, cut_min=5.25650e9, cut_max=5.25775e9, initial_params=initial_params)



print("-------------------------- -55dBm --------------------------------")
initial_params = {
    'a': a,
    'b': b,
    'c': c,
    'd': d,
    'k': k,
    'phi': phi,
    'Qt': qt,
    'Qc': qc,
    'fr': 5257200000
}
file_path = f"Cavity_resonances_40mK/Res2/risonanza/res2-55dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path, cut_min=5.25650e9, cut_max=5.25775e9, initial_params=initial_params)



print("-------------------------- -50dBm --------------------------------")
initial_params = {
    'a': a,
    'b': b,
    'c': c,
    'd': d,
    'k': k,
    'phi': phi,
    'Qt': qt,
    'Qc': qc,
    'fr': fr
}
file_path = f"Cavity_resonances_40mK/Res2/risonanza/res2-50dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path, cut_min=5.25650e9, cut_max=5.25775e9, initial_params=initial_params)



print("-------------------------- -45dBm --------------------------------")
initial_params = {
    'a': a,
    'b': b,
    'c': c,
    'd': d,
    'k': k,
    'phi': phi,
    'Qt': qt,
    'Qc': qc,
    'fr': fr
}
file_path = f"Cavity_resonances_40mK/Res2/risonanza/res2-45dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path, cut_min=5.25650e9, cut_max=5.25775e9, initial_params=initial_params)


print("-------------------------- -40dBm --------------------------------")
initial_params = {
    'a': a,
    'b': b,
    'c': c,
    'd': d,
    'k': k,
    'phi': phi,
    'Qt': qt,
    'Qc': qc,
    'fr': fr
}
file_path = f"Cavity_resonances_40mK/Res2/risonanza/res2-40dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path, cut_min=5.25650e9, cut_max=5.25775e9, initial_params=initial_params)



print("-------------------------- -35dBm --------------------------------")
initial_params = {
    'a': a,
    'b': b,
    'c': c,
    'd': d,
    'k': k,
    'phi': phi,
    'Qt': 19999,
    'Qc': qc,
    'fr': 5257000000
}
file_path = f"Cavity_resonances_40mK/Res2/risonanza/res2-35dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path, cut_min=5.25650e9, cut_max=5.25775e9, initial_params=initial_params)
# Out:
# -------------------------- -60dBm --------------------------------
# Successo del fit: True
# Chi quadro ridotto: 564.8543362292679
# a = 0.099 +/- 0.000
# b = -0.000 +/- 0.000
# c = -0.000 +/- 0.000
# d = 0.000 +/- 0.000
# k = 0.836 +/- 0.000
# phi = -0.095 +/- 0.000
# Qt = 14826.144 +/- 0.112
# Qc = 19192.812 +/- 0.137
# fr = 5257116192.397 +/- 21.517
# -------------------------- -55dBm --------------------------------
# Successo del fit: True
# Chi quadro ridotto: 194.7800235203458
# a = -0.043 +/- 0.000
# b = 0.000 +/- 0.000
# c = -0.000 +/- 0.000
# d = -0.000 +/- 0.000
# k = 1.018 +/- 0.000
# phi = -0.039 +/- 0.000
# Qt = 16062.233 +/- 0.080
# Qc = 24296.899 +/- 0.103
# fr = 5257105342.507 +/- 14.035
# -------------------------- -50dBm --------------------------------
# Successo del fit: True
# Chi quadro ridotto: 62.546994644115294
# a = -0.053 +/- 0.000
# b = -0.000 +/- 0.000
# c = 0.000 +/- 0.000
# d = -0.000 +/- 0.000
# k = 1.034 +/- 0.000
# phi = -0.058 +/- 0.000
# Qt = 16529.809 +/- 0.087
# Qc = 25056.839 +/- 0.113
# fr = 5257107120.881 +/- 14.489
# -------------------------- -45dBm --------------------------------
# Successo del fit: True
# Chi quadro ridotto: 20.53312068490841
# a = 0.021 +/- 0.000
# b = 0.000 +/- 0.000
# c = 0.000 +/- 0.000
# d = -0.000 +/- 0.000
# k = 0.978 +/- 0.000
# phi = -0.036 +/- 0.000
# Qt = 16138.554 +/- 0.075
# Qc = 22303.145 +/- 0.094
# fr = 5257102133.601 +/- 12.596
# -------------------------- -40dBm --------------------------------
# Successo del fit: True
# Chi quadro ridotto: 8.423051141767127
# a = 0.030 +/- 0.000
# b = 0.000 +/- 0.000
# c = 0.000 +/- 0.000
# d = -0.000 +/- 0.000
# k = 0.966 +/- 0.000
# phi = 0.024 +/- 0.000
# Qt = 16692.040 +/- 0.060
# Qc = 22301.053 +/- 0.074
# fr = 5257083565.567 +/- 9.237
# -------------------------- -35dBm --------------------------------
# Successo del fit: True
# Chi quadro ridotto: 25.081878474449223
# a = -0.035 +/- 0.000
# b = 0.000 +/- 0.000
# c = 0.000 +/- 0.000
# d = -0.000 +/- 0.000
# k = 0.998 +/- 0.000
# phi = 0.210 +/- 0.000
# Qt = 18991.371 +/- 0.051
# Qc = 26270.301 +/- 0.062
# fr = 5257028181.736 +/- 6.186

# %% [markdown]
# # RISONANZA 3 (40mK) al variare della potenza

# %%
print("-------------------------- -60dBm --------------------------------")
initial_params = {
    'a': 0.02,
    'b': 10e-9,
    'c': 10e-18,
    'd': 10e-27,
    'k': 0.936,
    'phi': 0.083,
    'Qt': 16664,
    'Qc': 23589,
    'fr': 4395801533
}
file_path = f"Cavity_resonances_40mK/Res3/risonanza/res3-60dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path, cut_min=5.8110e9, cut_max=5.8135e9, initial_params=initial_params)



print("-------------------------- -55dBm --------------------------------")
initial_params = {
    'a': a,
    'b': b,
    'c': c,
    'd': d,
    'k': k,
    'phi': phi,
    'Qt': qt,
    'Qc': qc,
    'fr': 5257200000
}
file_path = f"Cavity_resonances_40mK/Res3/risonanza/res3-55dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path, cut_min=5.8110e9, cut_max=5.8135e9, initial_params=initial_params)



print("-------------------------- -50dBm --------------------------------")
initial_params = {
    'a': a,
    'b': b,
    'c': c,
    'd': d,
    'k': k,
    'phi': phi,
    'Qt': qt,
    'Qc': qc,
    'fr': fr
}
file_path = f"Cavity_resonances_40mK/Res3/risonanza/res3-50dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path, cut_min=5.8110e9, cut_max=5.8135e9, initial_params=initial_params)



print("-------------------------- -45dBm --------------------------------")
initial_params = {
    'a': a,
    'b': b,
    'c': c,
    'd': d,
    'k': k,
    'phi': phi,
    'Qt': qt,
    'Qc': qc,
    'fr': fr
}
file_path = f"Cavity_resonances_40mK/Res3/risonanza/res3-45dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path, cut_min=5.8110e9, cut_max=5.8135e9, initial_params=initial_params)


print("-------------------------- -40dBm --------------------------------")
initial_params = {
    'a': a,
    'b': b,
    'c': c,
    'd': d,
    'k': k,
    'phi': phi,
    'Qt': qt,
    'Qc': qc,
    'fr': fr
}
file_path = f"Cavity_resonances_40mK/Res3/risonanza/res3-40dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path, cut_min=5.8110e9, cut_max=5.8135e9, initial_params=initial_params)



print("-------------------------- -35dBm --------------------------------")
initial_params = {
    'a': a,
    'b': b,
    'c': c,
    'd': d,
    'k': k,
    'phi': phi,
    'Qt': 19999,
    'Qc': qc,
    'fr': 5257000000
}
file_path = f"Cavity_resonances_40mK/Res3/risonanza/res3-35dBm.txt"
fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit_cut(file_path, cut_min=5.8110e9, cut_max=5.8135e9, initial_params=initial_params)
# Out:
# -------------------------- -60dBm --------------------------------
# Successo del fit: False
# Chi quadro ridotto: 729.8251740765357
# a = -3.967 +/- 0.000
# b = -0.000 +/- 0.000
# c = -0.000 +/- 0.000
# d = 0.000 +/- 0.000
# k = 4.871 +/- 0.000
# phi = 0.261 +/- 0.000
# Qt = 10552.654 +/- 0.081
# Qc = 68539.539 +/- 0.379
# fr = 5811926000.157 +/- 0.490
# -------------------------- -55dBm --------------------------------
# Successo del fit: True
# Chi quadro ridotto: 267.2855324850443
# a = -3.971 +/- 0.000
# b = -0.000 +/- 0.000
# c = -0.000 +/- 0.000
# d = 0.000 +/- 0.000
# k = 4.866 +/- 0.000
# phi = 0.472 +/- 0.000
# Qt = 10698.419 +/- 0.196
# Qc = 68945.670 +/- 0.927
# fr = 5811885000.000 +/- 7.635
# -------------------------- -50dBm --------------------------------
# Successo del fit: False
# Chi quadro ridotto: 175.34971973048889
# a = -25.960 +/- 0.000
# b = -0.000 +/- 0.000
# c = -0.000 +/- 0.000
# d = 0.000 +/- 0.000
# k = 26.890 +/- 0.000
# phi = 0.352 +/- 0.000
# Qt = 10881.791 +/- 0.059
# Qc = 378260.117 +/- 1.465
# fr = 5811915000.309 +/- 0.474
# -------------------------- -45dBm --------------------------------
# Successo del fit: True
# Chi quadro ridotto: 74.11660958679676
# a = -25.967 +/- 0.000
# b = -0.000 +/- 0.000
# c = -0.000 +/- 0.000
# d = 0.000 +/- 0.000
# k = 26.884 +/- 0.000
# phi = 0.431 +/- 0.000
# Qt = 11247.620 +/- 0.398
# Qc = 387778.499 +/- 9.919
# fr = 5811900000.000 +/- 14.108
# -------------------------- -40dBm --------------------------------
# Successo del fit: True
# Chi quadro ridotto: 91.23451895367869
# a = -25.956 +/- 0.000
# b = -0.000 +/- 0.000
# c = -0.000 +/- 0.000
# d = 0.000 +/- 0.000
# k = 26.895 +/- 0.000
# phi = 0.380 +/- 0.000
# Qt = 11113.871 +/- 0.231
# Qc = 373066.952 +/- 5.554
# fr = 5811905000.000 +/- 3.029
# -------------------------- -35dBm --------------------------------
# Successo del fit: True
# Chi quadro ridotto: 64.7189113282531
# a = -25.957 +/- 0.000
# b = -0.000 +/- 0.000
# c = -0.000 +/- 0.000
# d = 0.000 +/- 0.000
# k = 26.894 +/- 0.000
# phi = 0.450 +/- 0.000
# Qt = 11146.935 +/- 0.565
# Qc = 365710.740 +/- 13.536
# fr = 5811875000.000 +/- 21.572

# %% [markdown]
# # FIT QUARTA RISONANZA 40mK AL VARIARE DELLA POTENZA

# %%
y = []
dBm = [35, 40, 45, 50, 55, 60]

fr_list = []
Qc_list = []
Qt_list = []
a_list = []
b_list = []
c_list = []
d_list = []
k_list = []
phi_list = []


initial_params = {
    'a': 1,  # Ultimo valore di fr ottenuto
    'b': 10e-9,  # Ultimo valore di Qc ottenuto
    'c': 10e-18,       # Impostazione predefinita per c, d, k, phi, Qt, Qc, fr
    'd': 10e-27,
    'k': 1,
    'phi': 0.01,
    'Qt': 14310,
    'Qc': 22770,
    'fr': 6202500000  # Ultima frequenza di risonanza come valore iniziale
}

for pow in dBm:
    file_path = f"Cavity_resonances_40mK/Res4/risonanza/res4-{pow}dBm.txt"
    fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit(file_path, initial_params=initial_params)

    fr_list.append(fr)
    Qc_list.append(qc)
    Qt_list.append(qt)
    a_list.append(a)
    b_list.append(b)
    c_list.append(c)
    d_list.append(d)
    k_list.append(k)
    phi_list.append(phi)

    # Usa i parametri ottenuti dal fit precedente come parametri iniziali per il prossimo fit
    initial_params = {
        'a': 1,  # Ultimo valore di fr ottenuto
        'b': 10e-9,  # Ultimo valore di Qc ottenuto
        'c': 10e-18,       # Impostazione predefinita per c, d, k, phi, Qt, Qc, fr
        'd': 10e-27,
        'k': 3,
        'phi': 0.292,
        'Qt': Qt_list[-1],
        'Qc': Qc_list[-1],
        'fr': fr_list[-1]  # Ultima frequenza di risonanza come valore iniziale
    }
# Out:
# Successo del fit: False
# Chi quadro ridotto: 12.014799281808989
# a = -3.316 +/- 0.000
# b = 0.000 +/- 0.000
# c = 0.000 +/- 0.000
# d = 0.000 +/- 0.000
# k = 4.276 +/- 0.000
# phi = 0.438 +/- 0.000
# Qt = 14552.543 +/- 0.017
# Qc = 78144.213 +/- 0.065
# fr = 6235730012.412 +/- 1.325
# Successo del fit: True
# Chi quadro ridotto: 17.928025376422276
# a = -1.037 +/- 0.000
# b = 0.000 +/- 0.000
# c = 0.000 +/- 0.000
# d = 0.000 +/- 0.000
# k = 1.995 +/- 0.000
# phi = 0.386 +/- 0.000
# Qt = 13555.949 +/- 0.374
# Qc = 34717.663 +/- 0.724
# fr = 6235750000.000 +/- 15.193
# Successo del fit: True
# Chi quadro ridotto: 32.03618867850323
# a = -0.573 +/- 0.000
# b = 0.000 +/- 0.000
# c = 0.000 +/- 0.000
# d = 0.000 +/- 0.000
# k = 1.527 +/- 0.000
# phi = 0.362 +/- 0.000
# Qt = 12860.913 +/- 0.286
# Qc = 25641.741 +/- 0.444
# fr = 6235755000.000 +/- 7.674
# Successo del fit: False
# Chi quadro ridotto: 88.55865448321448
# a = -2.423 +/- 0.000
# b = 0.000 +/- 0.000
# c = 0.000 +/- 0.000
# d = 0.000 +/- 0.000
# k = 3.368 +/- 0.000
# phi = 0.389 +/- 0.000
# Qt = 13789.355 +/- 0.035
# Qc = 62154.590 +/- 0.117
# fr = 6235765000.915 +/- 0.872
# Successo del fit: True
# Chi quadro ridotto: 210.63577345384923
# a = -1.024 +/- 0.000
# b = -0.000 +/- 0.000
# c = 0.000 +/- 0.000
# d = 0.000 +/- 0.000
# k = 1.951 +/- 0.000
# phi = 0.360 +/- 0.000
# Qt = 13117.680 +/- 0.182
# Qc = 35181.790 +/- 0.369
# fr = 6235765000.000 +/- 4.034
# Successo del fit: False
# Chi quadro ridotto: 655.5244126052486
# a = -7.501 +/- 0.000
# b = -0.000 +/- 0.000
# c = -0.000 +/- 0.000
# d = 0.000 +/- 0.000
# k = 8.423 +/- 0.000
# phi = 0.345 +/- 0.000
# Qt = 13969.922 +/- 0.230
# Qc = 164927.789 +/- 1.948
# fr = 6235785000.001 +/- 0.718
