# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
import iminuit as minuit
from iminuit import Minuit
from iminuit.cost import LeastSquares
sys.path.append("../../fit")
import resonance_fit

# %% [markdown]
# # FIT 4 RISONANZE A 1 K

# %% [markdown]
# # FIT PRIMA RISONANZA 1K -50dBm

# %%
file_path = f"Cavity_resonances_1K/res1-50dBm.txt"


initial_params = {
    'a': 1,  # Ultimo valore di fr ottenuto
    'b': 10e-9,  # Ultimo valore di Qc ottenuto
    'c': 10e-18,       # Impostazione predefinita per c, d, k, phi, Qt, Qc, fr
    'd': 10e-27,
    'k': 2.5,
    'phi': 0.04,
    'Qt': 16703,
    'Qc': 24080,
    'fr': 4395812616  # Ultima frequenza di risonanza come valore iniziale
}


fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit(file_path, initial_params=initial_params)
# Out:
# Successo del fit: True
# Chi quadro ridotto: 18.532352769595317
# a = -0.008 +/- 0.000
# b = 0.000 +/- 0.000
# c = 0.000 +/- 0.000
# d = -0.000 +/- 0.000
# k = 1.003 +/- 0.000
# phi = 0.051 +/- 0.000
# Qt = 20264.545 +/- 0.145
# Qc = 26383.690 +/- 0.180
# fr = 4395332070.628 +/- 12.585

# %% [markdown]
# # FIT SECONDA RISONANZA 1K -50dBm

# %%
file_path = f"Cavity_resonances_1K/res2-50dBm.txt"


initial_params = {
    'a': 1,  # Ultimo valore di fr ottenuto
    'b': 10e-9,  # Ultimo valore di Qc ottenuto
    'c': 10e-18,       # Impostazione predefinita per c, d, k, phi, Qt, Qc, fr
    'd': 10e-27,
    'k': 2.5,
    'phi': 0.42,
    'Qt': 10000,
    'Qc': 75000,
    'fr': 5809178611  # Ultima frequenza di risonanza come valore iniziale
}



fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit(file_path, initial_params=initial_params)
# Out:
# Successo del fit: True
# Chi quadro ridotto: 26.077293919147095
# a = 0.001 +/- 0.000
# b = 0.000 +/- 0.000
# c = 0.000 +/- 0.000
# d = -0.000 +/- 0.000
# k = 0.995 +/- 0.000
# phi = -0.054 +/- 0.000
# Qt = 18143.456 +/- 0.126
# Qc = 22441.230 +/- 0.157
# fr = 5256576866.431 +/- 15.827

# %% [markdown]
# # FIT TERZA RISONANZA 1K -50dBm

# %%
file_path = f"Cavity_resonances_1K/res3-50dBm.txt"

initial_params = {
    'a': 1,  # Ultimo valore di fr ottenuto
    'b': 10e-9,  # Ultimo valore di Qc ottenuto
    'c': 10e-18,       # Impostazione predefinita per c, d, k, phi, Qt, Qc, fr
    'd': 10e-27,
    'k': 2.5,
    'phi': 0.42,
    'Qt': 10000,
    'Qc': 75000,
    'fr': 5809178611  # Ultima frequenza di risonanza come valore iniziale
}



fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit(file_path, initial_params=initial_params)
# Out:
# Successo del fit: False
# Chi quadro ridotto: 137.15106839626964
# a = -13.681 +/- 0.000
# b = -0.000 +/- 0.000
# c = -0.000 +/- 0.000
# d = 0.000 +/- 0.000
# k = 14.588 +/- 0.000
# phi = 0.504 +/- 0.000
# Qt = 11790.318 +/- 0.062
# Qc = 209073.656 +/- 0.796
# fr = 5811329601.939 +/- 0.806

# %% [markdown]
# # FIT QUARTA RISONANZA 1K -50dBm

# %%
file_path = f"Cavity_resonances_1K/res4-50dBm.txt"



initial_params = {
    'a': 1,  # Ultimo valore di fr ottenuto
    'b': 10e-9,  # Ultimo valore di Qc ottenuto
    'c': 10e-18,       # Impostazione predefinita per c, d, k, phi, Qt, Qc, fr
    'd': 10e-27,
    'k': 1,
    'phi': 0.01,
    'Qt': 14310,
    'Qc': 22770,
    'fr': 6202500000  # Ultima frequenza di risonanza come valore iniziale
}


fr, qc, qt, a, b, c, d, k, phi = resonance_fit.fit(file_path, initial_params=initial_params)
# Out:
# Successo del fit: True
# Chi quadro ridotto: 41.23661685990427
# a = -0.365 +/- 0.000
# b = 0.000 +/- 0.000
# c = 0.000 +/- 0.000
# d = 0.000 +/- 0.000
# k = 1.318 +/- 0.000
# phi = 0.342 +/- 0.000
# Qt = 13552.661 +/- 0.634
# Qc = 21988.922 +/- 0.839
# fr = 6235201600.000 +/- 19.688
