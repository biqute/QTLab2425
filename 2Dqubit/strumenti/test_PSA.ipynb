# %%
from PSA import PSA
import matplotlib.pyplot as plt
import numpy as np


ip = '192.168.40.10'

psa = PSA(ip)
psa.set_freq_span(5, 1)
psa.set_sweep_points(801)
psa.set_n_means(20)
# Out:
# device connected.
# '1\n'

# %%
from PSA import PSA
import matplotlib.pyplot as plt
import numpy as np


ip = '192.168.40.10'

psa = PSA(ip)
"""
psa.set_freq_span(5, 1)
psa.set_sweep_points(801)
psa.set_n_means(20)

fig, axs = plt.subplots (1, 1)

min , max = psa.get_freq_limits()
n_points = psa.get_sweep_points()
freq = np.linspace(min , max, n_points)



amp = psa.get_trace()
print(psa.get_n_means())

axs.set_title("20 means")
axs.set_xlabel("Frequency [Hz]")
axs.set_ylabel("Amplitude [dBm]")
axs.plot(freq, amp)

plt.show()

psa.set_n_means(10000)

fig, axs = plt.subplots (1, 1)
amp_new = psa.get_trace()
print (psa.get_n_means())

axs.set_title("4000 means")
axs.set_xlabel("Frequency [Hz]")
axs.set_ylabel("Amplitude [dBm]")
axs.plot(freq, amp_new)


plt.show()"""
# Out:
# device connected.

# %%
# Out:
# 10000
