# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
import iminuit as minuit
from iminuit import Minuit
from iminuit.cost import LeastSquares
sys.path.append("..")
from fitLk import lettura_csv
from fitLk import trova_minimi
from fitLk import lkvfr
from fitLk import lkvfr_tot
from fitLk import fit
from fitLk import calcolo_lk
from fitLk import cut
from fitLk import selected_cut

# %% [markdown]
# ## RISONATORE 1

# %%
col_1, col_2 = lettura_csv("Risonatore_1\DARTWARS_TestChip_res1_w1_l280_param\Graph1.csv")

f_min1, Lk1 = trova_minimi(col_1, col_2, discarded_Lk=[0, 15.0, 15.5, 16.0, 16.5, 17.0, 17.5, 18.0, 18.5, 19.0, 19.5, 20.0])
lkvfr (Lk1, f_min1)

a, b, g = fit (Lk1, f_min1)

fr1 = 4.395812616743 #frequenza di risonanza ottenuta dal fit a 40mK
x1 = calcolo_lk(a, b, g, fr1)
print("Induttanza cinetica calcolata con i parametri del fit: ", x1)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\franc\AppData\Local\Temp\ipykernel_10708\1295416211.py:1: SyntaxWarning: invalid escape sequence '\D'
#   col_1, col_2 = lettura_csv("Risonatore_1\DARTWARS_TestChip_res1_w1_l280_param\Graph1.csv")
# Successo del fit: True
# Chi-quadro ridotto: 2.6383353978375635e-05
# a = 15.988 ± 4.272
# b = 0.002 ± 0.893
# g = 1.437 ± 1.731
# c:\Users\franc\Documents\UNI\QTLab2425\2Dqubit\Simulation\Runs\fitLk.py:188: RuntimeWarning: invalid value encountered in sqrt
#   return ((a / np.sqrt(Lk + g)) + b)
# c:\Users\franc\Documents\UNI\QTLab2425\2Dqubit\Simulation\Runs\fitLk.py:214: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "bo" (-> marker='o'). The keyword argument will take precedence.
#   ax.plot(x, y, "bo", label="Dati sperimentali", marker="o", markersize=2, linestyle="none")
# ...

# %% [markdown]
# ## RISONATORE 2

# %%
col_1, col_2 = lettura_csv("Risonatore_2\DARTWARS_TestChip_res2_w2_l320_param\Graph2_NEW_GIUSTO.csv")
f_min2, Lk2 = trova_minimi(col_1, col_2, discarded_Lk=[0, 14.5])
lkvfr (Lk2, f_min2)
a, b, g = fit (Lk2, f_min2)
fr2 =  5.257107641625#frequenza di risonanza ottenuta dal fit a 40mK
x2 = calcolo_lk(a, b, g, fr2)
print("Induttanza cinetica calcolata con i parametri del fit: ", x2)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\franc\AppData\Local\Temp\ipykernel_10708\4208032668.py:1: SyntaxWarning: invalid escape sequence '\D'
#   col_1, col_2 = lettura_csv("Risonatore_2\DARTWARS_TestChip_res2_w2_l320_param\Graph2_NEW_GIUSTO.csv")
# Successo del fit: True
# Chi-quadro ridotto: 0.002233226110649382
# a = 20.033 ± 5.764
# b = -0.044 ± 1.130
# g = 2.666 ± 2.134
# Induttanza cinetica calcolata con i parametri del fit:  11.613220069607305

# %% [markdown]
# ## RISONATORE 3

# %%
col_1, col_2 = lettura_csv("Risonatore_3\DARTWARS_TestChip_res3_w1_tunable_l75_param\Graph3.csv")
col_1, col_2 = cut(col_1, col_2, 0, 9)
col_1, col_2 =selected_cut(col_1, col_2, [7.0], 0, 8.0)
col_1, col_2 =selected_cut(col_1, col_2, [7.5, 8.0, 8.5, 9.0, 9.5, 10.0, 10.5], 0, 7)
col_1, col_2 =selected_cut(col_1, col_2, [11.0, 11.5], 0, 6.5)
col_1, col_2 =selected_cut(col_1, col_2, [12.0, 12.5, 13.0, 13.5, 14.0, 14.5], 0, 6)
col_1, col_2 =selected_cut(col_1, col_2, [15.0], 0, 5.4)

discarded_Lk = []

f_min3, Lk3 = trova_minimi(col_1, col_2, discarded_Lk)
lkvfr (Lk3, f_min3)

a, b, g = fit (Lk3, f_min3)

fr3 =  5.811921846687#frequenza di risonanza ottenuta dal fit a 40mK
x3 = calcolo_lk(a, b, g, fr3)
print("Induttanza cinetica calcolata con i parametri del fit: ", x3)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\franc\AppData\Local\Temp\ipykernel_10708\477479545.py:1: SyntaxWarning: invalid escape sequence '\D'
#   col_1, col_2 = lettura_csv("Risonatore_3\DARTWARS_TestChip_res3_w1_tunable_l75_param\Graph3.csv")
# Successo del fit: True
# Chi-quadro ridotto: 0.010324763972057909
# a = 21.884 ± 3.476
# b = -0.009 ± 0.706
# g = 2.522 ± 1.080
# Induttanza cinetica calcolata con i parametri del fit:  11.611857781848453

# %% [markdown]
# ## RISONATORE 4

# %%
col_1, col_2 = lettura_csv("Risonatore_4\DARTWARS_TestChip_res4_w2_tunable_l90_param\Graph4_0-8.csv")

col_1, col_2 = selected_cut(col_1, col_2, [9.5, 10.0, 10.5, 11.0, 11.5, 12.0], 0, 7)
col_1, col_2 = selected_cut(col_1, col_2, [11.0, 11.5], 0, 6.5)
col_1, col_2 = selected_cut(col_1, col_2, [12.5, 13.0, 13.5, 14.0, 14.5, 15.0], 0, 6.3)
discarded_Lk = [0]
f_min4, Lk4 = trova_minimi(col_1, col_2, discarded_Lk)
lkvfr (Lk4, f_min4)

a, b, g = fit (Lk4, f_min4)

fr4 =  6.235765000000#frequenza di risonanza ottenuta dal fit a 40mK
x4 = calcolo_lk(a, b, g, fr4)
print("Induttanza cinetica calcolata con i parametri del fit: ", x4)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\franc\AppData\Local\Temp\ipykernel_10708\630409245.py:1: SyntaxWarning: invalid escape sequence '\D'
#   col_1, col_2 = lettura_csv("Risonatore_4\DARTWARS_TestChip_res4_w2_tunable_l90_param\Graph4_0-8.csv")
# Successo del fit: True
# Chi-quadro ridotto: 0.01886839542459085
# a = 24.946 ± 10.515
# b = -0.087 ± 1.875
# g = 4.153 ± 3.840
# Induttanza cinetica calcolata con i parametri del fit:  11.410220300661237

# %%
lk_mean = (x1 + x2 + x3 + x4) / 4
local_Lk = [x1, x2, x3, x4]
print("Induttanza cinetica media: ", lk_mean)


int_freq = lkvfr_tot(Lk1, f_min1, Lk2, f_min2, Lk3, f_min3, Lk4, f_min4, lk_mean, local_Lk)
# Out:
# Induttanza cinetica media:  11.61076051358783
# Resonator 1:
#    - Lk locale fornito = 11.808
#    - f_res(Lk locale) = 4.3958 GHz
#    - f_res(Lk_mean)   = 4.42883209020223 GHz
# Resonator 2:
#    - Lk locale fornito = 11.613
#    - f_res(Lk locale) = 5.2571 GHz
#    - f_res(Lk_mean)   = 5.257515272057005 GHz
# Resonator 3:
#    - Lk locale fornito = 11.612
#    - f_res(Lk locale) = 5.8119 GHz
#    - f_res(Lk_mean)   = 5.812167083661806 GHz
# Resonator 4:
#    - Lk locale fornito = 11.410
#    - f_res(Lk locale) = 6.2359 GHz
#    - f_res(Lk_mean)   = 6.1955579516512 GHz
