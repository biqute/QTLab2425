# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
import iminuit as minuit
from iminuit import Minuit
from iminuit.cost import LeastSquares
sys.path.append("..")
from fitLk import lettura_csv
from fitLk import trova_minimi
from fitLk import lkvfr
from fitLk import fit
from fitLk import calcolo_lk

col_1, col_2 = lettura_csv(r"C:\Users\oper\labQT\Lab2024\QUBIT_2D\QTLab2425\2Dqubit\Simulation\sondata\Risonatore_2\DARTWARS_TestChip_res2_w1_l280_param\Graph2.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 14
#      11 from fitLk import fit
#      12 from fitLk import calcolo_lk
# ---> 14 col_1, col_2 = lettura_csv(r"C:\Users\oper\labQT\Lab2024\QUBIT_2D\QTLab2425\2Dqubit\Simulation\sondata\Risonatore_2\DARTWARS_TestChip_res2_w1_l280_param\Graph2.csv")
#
# File c:\Users\oper\labQT\Lab2024\QUBIT_3D\QTLab2425\2Dqubit\Simulation\sondata\Risonatore_2\..\fitLk.py:30, in lettura_csv(nome_file)
#      27     except ValueError:
#      28         return False
# ---> 30 with open(nome_file, newline='') as csvfile:
#      31     lettore = csv.reader(csvfile)
#      33     for riga in lettore:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\oper\\labQT\\Lab2024\\QUBIT_2D\\QTLab2425\\2Dqubit\\Simulation\\sondata\\Risonatore_2\\DARTWARS_TestChip_res2_w1_l280_param\\Graph2.csv'

# %%
f_min, Lk = trova_minimi(col_1, col_2, min_lk=0.5)
lkvfr (Lk, f_min)

# %%
a, b, g = fit (Lk, f_min)
# Out:
# c:\Users\oper\labQT\Lab2024\QUBIT_3D\QTLab2425\2Dqubit\Simulation\sondata\Risonatore_1\..\fitLk.py:128: RuntimeWarning: invalid value encountered in sqrt
#   return ((a/(np.sqrt(Lk+g)))+b)
# c:\Users\oper\labQT\Lab2024\QUBIT_3D\QTLab2425\2Dqubit\Simulation\sondata\Risonatore_1\..\fitLk.py:158: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "bo" (-> marker='o'). The keyword argument will take precedence.
#   ax.plot(x, y, "bo", label="Dati sperimentali", marker="o", markersize=2, linestyle="none")
# Successo del fit: True
# Chi-quadro ridotto: 3.624864241793811e-05
# a = 15.995 ± 4.278
# b = 0.001 ± 0.894
# g = 1.441 ± 1.733

# %%
fr = 4.39575 #frequenza di risonanza ottenuta dal fit a 40mK
x = calcolo_lk(a, b, g, fr)
print("Induttanza cinetica calcolata con i parametri del fit: ", x)
# Out:
# Induttanza cinetica calcolata con i parametri del fit:  11.808884036873618
