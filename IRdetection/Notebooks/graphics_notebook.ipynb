# %%
import matplotlib.pyplot as plt
import numpy as np

import sys
import os

sys.path.append(os.path.join(os.getcwd(), ".."))
from src.graphics.plotting import set_plotting_style
from src.graphics.colours import Palette
from src.graphics.typography import Typography, Font

# %%
from matplotlib import style


my_typography = Typography(
    title=Font(font="Palatino Linotype", family="sans-serif", size=18),
    subtitle=Font(font="Calibri", family="sans-serif", size=16),
    body=Font(font="Arial", family="sans-serif", size=14),
    caption=Font(font="Comic Sans MS", family="sans-serif", size=12),
)

my_palette = Palette(name='pippo',colours='5f0f40-9a031e-fb8b24-e36414-0f4c5c')
my_palette.neutral_dark = "#1e1e1e"

set_plotting_style(typography=my_typography, palette=my_palette, style_type='notebook')

# %%
# Sample scatter plot
from cProfile import label


dummy_data = np.sin(np.linspace(0, 10, 100))
dummy_data_2 = np.cos(np.linspace(0, 10, 100))
plt.figure(figsize=(10, 6))
plt.scatter(np.linspace(0, 10, 100), dummy_data, label='Sample Data')
plt.plot(np.linspace(0, 10, 100), dummy_data_2, color='red', label='Sample Line')
plt.title("Sample Scatter Plot")
plt.xlabel("X-axis Label")
plt.ylabel("Y-axis Label")
plt.grid(True)
plt.legend()
plt.show()
